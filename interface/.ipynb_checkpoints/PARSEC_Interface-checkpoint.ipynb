# %%
# %load_ext autoreload
# %autoreload 2
import signal
import time
from custom_widgets import password
import os
from dsapol import parsec
from dsapol import polbeamform
from dsapol import polcal
from dsapol import dedisp
from dsapol import filt
from dsapol import RMcal
from dsapol import rmtablefuncs
from dsapol import customfilplotfuncs
from dsapol import scatscint
#from dsapol import widget
import numpy as np
import matplotlib
# %matplotlib inline
from matplotlib import pyplot as plt
from dsapol import dsapol
from scipy.signal import correlate
from scipy.signal import savgol_filter as sf
from scipy.signal import convolve
from scipy.signal import fftconvolve
from scipy.ndimage import convolve1d
from scipy.signal import peak_widths
from scipy.stats import chi
from scipy.stats import norm
import copy
import glob
import csv
import corner
from IPython.display import display, Math

import matplotlib.image as mpimg
from numpy.ma import masked_array as ma
from scipy.stats import kstest
from scipy.optimize import curve_fit


from scipy.signal import find_peaks
from scipy.signal import peak_widths
import copy
import numpy as np

from sigpyproc import FilReader
from sigpyproc.Filterbank import FilterbankBlock
from sigpyproc.Header import Header
from matplotlib import pyplot as plt
import pylab
import pickle
import json
from scipy.interpolate import interp1d
from scipy.stats import chi2
from scipy.stats import chi
from scipy.signal import savgol_filter as sf
from scipy.signal import convolve
from scipy.ndimage import convolve1d
from RMtools_1D.do_RMsynth_1D import run_rmsynth
from RMtools_1D.do_RMclean_1D import run_rmclean
from RMtools_1D.do_QUfit_1D_mnest import run_qufit
from astropy.time import Time
from astropy.coordinates import EarthLocation
import astropy.units as u

import pandas as pd
pd.option_context('display.max_rows', 3)
import mercury as mr
import warnings

import json
from tqdm.notebook import tqdm
from scattering import scat
from scintillation import scint
from PIL import Image
# Out:
# /home/ubuntu/msherman_nsfrb/miniconda/envs/casa38dsapol/lib/python3.8/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Some or all of the expected auto updates did not happen.
# This indicates that measurespath is not empty and does not contain data maintained by casaconfig.
# If the IERSeop2000 table is found in datapth then casatools will import.
#
# The casa data found at measurespath is not being maintained by casaconfig.
# visit https://casadocs.readthedocs.io/en/stable/notebooks/external-data.html for more information
# 2024-10-24 19:18:01	SEVERE		Unknown observatory asked for
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 7
#       5 from custom_widgets import password
#       6 import os
# ----> 7 from dsapol import parsec
#       8 from dsapol import polbeamform
#       9 from dsapol import polcal
#
# File ~/msherman_nsfrb/miniconda/envs/casa38dsapol/lib/python3.8/site-packages/dsapol/parsec.py:34
#      32 from scipy.stats import kstest
#      33 from scipy.optimize import curve_fit
# ---> 34 from syshealth.status_mon import get_rm
#      35 from bilby.core import result as bcresult
#      36 from scipy.signal import find_peaks
#
# File ~/msherman_nsfrb/miniconda/envs/casa38dsapol/lib/python3.8/site-packages/syshealth/status_mon.py:13
#      10 from influxdb import DataFrameClient
#      11 import h5py
# ---> 13 import dsacalib.constants as ct
#      14 from dsautils import dsa_store
#      15 import dsautils.dsa_syslog as dsl
#
# File ~/msherman_nsfrb/miniconda/envs/casa38dsapol/lib/python3.8/site-packages/dsacalib/constants.py:36
#      34 me = cc.measures()
#      35 ovro_loc = me.observatory("OVRO-LWA")
# ---> 36 OVRO_LON = ovro_loc["m0"]["value"]
#      37 OVRO_LAT = ovro_loc["m1"]["value"]
#      38 OVRO_ALT = ovro_loc["m2"]["value"]
#
# KeyError: 'm0'

# %%
startup = Time.now()
ADMINMODE = False
app = mr.App(title="PARSEC DSA-110 Burst Analysis Dashboard (beta)", 
             stop_on_error=False,
             description="With this dashboard, you can conduct DM tuning, scattering analysis, scintillation analysis, RM synthesis, and polarization analysis.")
# Out:
# mercury.App

# %%
#setup logfiles for current session

#get timestamp
startup_isot = startup.isot

#create log dir
f = open(os.environ['DSAPOLDIR'] + "directories.json","r")
dirs = json.load(f)
f.close()
os.system("mkdir "+ dirs['logs'] + startup_isot)

#update logfile names for each submodule
dsapol.logfile = dirs["logs"] + startup_isot + "/dsapol_logfile.txt"
RMcal.logfile = dirs["logs"] + startup_isot + "/RMcal_logfile.txt"
rmtablefuncs.logfile = dirs["logs"] + startup_isot + "/archive_logfile.txt"
polbeamform.logfile = dirs["logs"] + startup_isot + "/beamform_logfile.txt"
dedisp.logfile = dirs["logs"] + startup_isot + "/dedisp_logfile.txt"
filt.logfile = dirs["logs"] + startup_isot + "/filter_logfile.txt"
polcal.logfile = dirs["logs"] + startup_isot + "/polcal_logfile.txt"
scatscint.logfile = dirs["logs"] + startup_isot + "/scatscint_logfile.txt"

#make clean logfiles
os.system("touch " + dirs["logs"] + startup_isot + "/beamform_logfile.txt")
os.system("touch " + dirs["logs"] + startup_isot + "/dedisp_logfile.txt")
os.system("touch " + dirs["logs"] + startup_isot + "/polcal_logfile.txt")
os.system("touch " + dirs["logs"] + startup_isot + "/filter_logfile.txt")
os.system("touch " + dirs["logs"] + startup_isot + "/RMcal_logfile.txt")
os.system("touch " + dirs["logs"] + startup_isot + "/dsapol_logfile.txt")
os.system("touch " + dirs["logs"] + startup_isot + "/archive_logfile.txt")
os.system("touch " + dirs["logs"] + startup_isot + "/scatscint_logfile.txt")

os.system("> " + dirs["logs"] + startup_isot + "/beamform_logfile.txt")
os.system("> " + dirs["logs"] + startup_isot + "/dedisp_logfile.txt")
os.system("> " + dirs["logs"] + startup_isot + "/polcal_logfile.txt")
os.system("> " + dirs["logs"] + startup_isot + "/filter_logfile.txt")
os.system("> " + dirs["logs"] + startup_isot + "/RMcal_logfile.txt")
os.system("> " + dirs["logs"] + startup_isot + "/dsapol_logfile.txt")
os.system("> " + dirs["logs"] + startup_isot + "/archive_logfile.txt")
os.system("> " + dirs["logs"] + startup_isot + "/scatscint_logfile.txt")

os.system("mkdir " + dirs["logs"] + startup_isot + "/RM_files")
os.system("mkdir " + dirs["logs"] + startup_isot + "/scat_files")

#os.system("mkdir ../interface/.current_state")
# Out:
# 0

# %%
adminbutton = mr.Button(label='Enable Administrator Mode',style='primary',hidden=False)
admini = 4
if adminbutton.clicked:
    admini = 0
# Out:
# mercury.Button

# %%
adminpw = password.customPassword(value="",label='Enter Administrator Password',
                                      unauthorized=parsec.unauthorized,
                                      incorrect=parsec.incorrect,
                                      key=parsec.dsapoladminkey,
                                      hidden=admini>=1)
admini += 1
if not ADMINMODE:
    if admini >1 and admini != 5:
        ADMINMODE = adminpw.checkpw()
    if ADMINMODE: print("Administrator mode enabled.")

admindisablebutton = mr.Button(label='Disable Administrator Mode',style='primary',hidden=False)
if admindisablebutton.clicked and ADMINMODE:
    ADMINMODE = False
    print("Administrator mode disabled.")
    
mr.Markdown(text=r'# Welcome to the PARSEC Burst Analysis Dashboard!')
mr.Markdown(text=r'## Current Mode: ' + str("ADMIN" if ADMINMODE else "USER"))
mr.Markdown(text=r'## Click the Arrow to Begin')
# Out:
# mercury.Text
# mercury.Button
# # Welcome to the PARSEC Burst Analysis Dashboard!
# ## Current Mode: USER
# ## Click the Arrow to Begin

# %%
# Toggle Sliders Button: switches between panels of widgets for different slides


if ADMINMODE:
    toggle_menu = mr.Select(label='Toggle Widget Panels',
                       value=parsec.wdict['toggle_menu'],
                       choices=['(ADMIN) Make Filterbanks',
                                '(0) Load Data',
                               '(1) Dedispersion Tuning',
                               '(ADMIN) Calibration -- Beamform Cal Voltages',
                               '(ADMIN) Calibration -- Make Cal Filterbanks',
                               '(ADMIN) Calibration -- Choose Cal Observations',
                               '(ADMIN) Calibration -- Make Cal Solutions (|gyy|)',#($|g_{yy}|$)',
                               '(ADMIN) Calibration -- Make Cal Solutions (|gxx|/|gyy|)',#($|g_{xx}|/|g_{yy}|$)',
                               '(ADMIN) Calibration -- Make Cal Solutions (<gxx - <gyy)',#($\angle g_{xx} - \angle g_{yy}$)',
                               '(2) Calibration -- Calibrate',
                               '(3) Filter Weights',
                               '(4) Scattering Analysis',
                               '(5) Scintillation Analysis',
                               '(6) RM Synthesis',
                               '(7) RM, DM, Bfield Budget',
                               '(8) Polarization Analysis',
                               '(9) Archive Data',
                               '(10) Help'])
else:
    toggle_menu = mr.Select(label='Toggle Widget Panels',
                       value=parsec.wdict['toggle_menu'],
                       choices=['(0) Load Data',
                               '(1) Dedispersion Tuning',
                               '(2) Calibration -- Calibrate',
                               '(3) Filter Weights',
                               '(4) Scattering Analysis',
                               '(5) Scintillation Analysis',
                               '(6) RM Synthesis',
                               '(7) RM, DM, Bfield Budget',
                               '(8) Polarization Analysis',
                               '(9) Archive Data',
                               '(10) Help'])

parsec.wdict['toggle_menu'] = toggle_menu.value
# Out:
# mercury.Select

# %%
savesessionbutton = mr.Button(label='Save Session',style='primary')
mdown = parsec.save_screen(savesessionbutton)
mr.Note(mdown)
# Out:
# mercury.Button
# mercury.Note
# mercury.Note

# %%
restoresessionbutton = mr.Button(label='Restore Session',style='primary')
restore_menu = mr.Select(label="Session to Restore:", 
                                value=parsec.wdict['restore_menu'],
                                choices=[""] + [i[len(dirs['cache']):] for i in glob.glob(dirs['cache']+"*")],
                                hidden=toggle_menu.value != '(0) Load Data')#frbfiles[0], choices=frbfiles,hidden=hidden)
    

mdown = parsec.restore_screen(restoresessionbutton,restore_menu)
mr.Note(mdown)
# Out:
# mercury.Button
# mercury.Select
# mercury.Note
# mercury.Note

# %%
#(0) LOAD DATA
def mywarning(message, category, filename, lineno, file=None, line=None,logfile=''):
    warning_file = open(logfile, "a")
    warning_file.write(warnings.formatwarning(message, category, filename, lineno, line))
    warning_file.close()




hidden = toggle_menu.value != '(ADMIN) Make Filterbanks'
if not hidden:
    warnings.showwarning = lambda message, category, filename, lineno, file, line : mywarning(message, category, filename, lineno, file, line, polbeamform.logfile)
    #frbfiles = parsec.get_frbfiles()
    frbfiles_menu = mr.Select(label="FRB (candname_nickname):", 
                                value=parsec.wdict['frbfiles_menu'],
                                choices=parsec.frbfiles,
                                hidden=hidden)#frbfiles[0], choices=frbfiles,hidden=hidden)
    

    updatebutton = mr.Button(label='Update FRB Params',style='primary',hidden=hidden)
    filbutton = mr.Button(label='Make Filterbanks',style='primary',hidden=hidden)

    RA_display = mr.NumberBox(data=parsec.wdict['RA_display'], title=r'RA ($^{\circ}$)')
    DEC_display = mr.NumberBox(data=parsec.wdict['DEC_display'], title=r'DEC ($^{\circ}$)')
    ibeam_display = mr.NumberBox(data=parsec.wdict['ibeam_display'], title=r'ibeam')
    ibox_display = mr.NumberBox(data=parsec.wdict['ibox_display'], title=r'ibox')
    mjd_display = mr.NumberBox(data=parsec.wdict['mjd_display'],title=r'MJD')
    DM_init_display = mr.NumberBox(data=parsec.wdict['DM_init_display'], 
                                title=r'DM (pc/cm$^{{3}}$)'
                               )
    z_display = mr.NumberBox(data=parsec.wdict['z_display'], 
                                title=r'Redshift z'
                               )

hidden = toggle_menu.value != '(0) Load Data'
if not hidden:
    warnings.showwarning = lambda message, category, filename, lineno, file, line : mywarning(message, category, filename, lineno, file, line, polbeamform.logfile)
    
    #frbfiles = parsec.get_frbfiles()
    frbfiles_menu = mr.Select(label="FRB (candname_nickname):", 
                                value=parsec.wdict['frbfiles_menu'],
                                choices=parsec.frbfiles,
                                hidden=hidden)#frbfiles[0], choices=frbfiles,hidden=hidden)
    
    
    #load polcal data
    polcalloadbutton = mr.Checkbox(value=parsec.wdict['polcalloadbutton'], 
                                   label="Load Pre-Calibrated Data",hidden=hidden)

#revised to make these for both load and dedisp screens
hidden= toggle_menu.value not in ['(1) Dedispersion Tuning','(0) Load Data']
if not hidden: 
    n_t_slider = mr.Slider( #time downsampling factor
        value=parsec.wdict['n_t_slider'],
        min=1, 
        max=128, 
        step=1, 
        label='nt'
    ,hidden=hidden)
    logn_f_slider = mr.Slider( #freq downsampling factor
        value=parsec.wdict['logn_f_slider'],
        min=0, 
        max=10, 
        step=1, 
        label='log2(nf)'
    ,hidden=hidden)
    
#revised to make these for both load and dedisp screens
hidden= (toggle_menu.value not in ['(1) Dedispersion Tuning','(0) Load Data','(3) Filter Weights','(4) Scattering Analysis','(6) RM Synthesis']) and ('(2)' not in toggle_menu.value)
if not hidden: 
    logwindow_slider = mr.Slider(
        value=parsec.wdict['logwindow_slider'],
        min=5, 
        max=9, 
        step=1, 
        label='log2(window)' + str(' [change window size to reset to initial guess scattering parameters]' if toggle_menu.value == '(4) Scattering Analysis' else "")#r'base ${\rm log_{2}}({\rm window})$'
    ,hidden=hidden)
    
hidden = toggle_menu.value != '(0) Load Data'
if not hidden:
    """base_n_t_slider = mr.Slider( #time downsampling factor
        value=parsec.wdict['base_n_t_slider'],
        min=1, 
        max=128, 
        step=1, 
        label=r'base nt'
    ,hidden=hidden)
    base_logn_f_slider = mr.Slider( #freq downsampling factor
        value=parsec.wdict['base_logn_f_slider'],
        min=0, 
        max=10, 
        step=1, 
        label=r'base log2(nf)'#r'base ${\rm log_{2}}({\rm n_f})$'
    ,hidden=hidden)
    logibox_slider_init = mr.Slider(
        value=parsec.wdict['logibox_slider_init'],
        min=0, 
        max=6, 
        step=1, 
        label=r'log2(ibox)'#r'${\rm log_{2}}({\rm ibox})$'
    ,hidden=hidden)

    buff_L_slider_init = mr.Slider(
        value=parsec.wdict['buff_L_slider_init'],
        min=1, 
        max=128, 
        step=1, 
        label=r'left buffer'#${\rm buff}_{L}$'
    ,hidden=hidden)
    buff_R_slider_init = mr.Slider(
        value=parsec.wdict['buff_R_slider_init'],
        min=1, 
        max=128, 
        step=1, 
        label=r'right buffer'#${\rm buff}_{R}$'
    ,hidden=hidden)"""


    #updatebutton = mr.Button(label='Update FRB Params',style='primary',hidden=hidden)
    #filbutton = mr.Button(label='Make Filterbanks',style='primary',hidden=hidden)
    loadbutton = mr.Button(label='Load FRB Data',style='primary',hidden=hidden)
    refreshlogbutton = mr.Button(label='Refresh Log',style='primary',hidden=hidden)




    #get parameters for default frb
    """ids = frbfiles_menu.value[:frbfiles_menu.value.index('_')]
    RA = parsec.FRB_RA[parsec.FRB_IDS.index(ids)]
    DEC = parsec.FRB_DEC[parsec.FRB_IDS.index(ids)]
    ibeam = int(parsec.FRB_BEAM[parsec.FRB_IDS.index(ids)])
    mjd = parsec.FRB_mjd[parsec.FRB_IDS.index(ids)]
    mjd_display = mr.NumberBox(data=mjd,title=r'MJD')
    DMinit = parsec.FRB_DM[parsec.FRB_IDS.index(ids)]
    """

    RA_display = mr.NumberBox(data=parsec.wdict['RA_display'], title=r'RA ($^{\circ}$)')
    DEC_display = mr.NumberBox(data=parsec.wdict['DEC_display'], title=r'DEC ($^{\circ}$)')
    ibeam_display = mr.NumberBox(data=parsec.wdict['ibeam_display'], title=r'ibeam')
    ibox_display = mr.NumberBox(data=parsec.wdict['ibox_display'], title=r'ibox')
    mjd_display = mr.NumberBox(data=parsec.wdict['mjd_display'],title=r'MJD')
    DM_init_display = mr.NumberBox(data=parsec.wdict['DM_init_display'], 
                                title=r'DM (pc/cm$^{{3}}$)'
                               )
    z_display = mr.NumberBox(data=parsec.wdict['z_display'], 
                                title=r'Redshift z'
                               )
    """logwindow_slider_dynspec = mr.Slider(
        value=parsec.wdict['logwindow_slider_dynspec'],
        min=5, 
        max=9, 
        step=1, 
        label=r'base log2(window)'#${\rm log_{2}}({\rm window})$'
    ,hidden=hidden)"""
    
#(1) DEDISPERSION

hidden=toggle_menu.value != '(1) Dedispersion Tuning'
if not hidden:
    warnings.showwarning = lambda message, category, filename, lineno, file, line : mywarning(message, category, filename, lineno, file, line, dedisp.logfile)
    
    #widgets for DM tuning dashboard
    """n_t_slider = mr.Slider( #time downsampling factor
        value=parsec.wdict['n_t_slider'],
        min=1, 
        max=128, 
        step=1, 
        label=r'nt'#$n_t$'
    ,hidden=hidden)
    logn_f_slider = mr.Slider( #freq downsampling factor
        value=parsec.wdict['logn_f_slider'],
        min=0, 
        max=10, 
        step=1, 
        label=r'log2(nf)'#'${\\rm log_{2}}(n_f)$'
    ,hidden=hidden)"""
    """logwindow_slider_init = mr.Slider(
        value=parsec.wdict['logwindow_slider_init'],
        min=5, 
        max=9, 
        step=1, 
        label=r'base (log2(window))'#${\rm log_{2}}({\rm window})$'
    ,hidden=hidden)"""
    
    ddm_num = mr.Numeric(value=parsec.wdict['ddm_num'], #DM offset
                         step=1e-3,
                         min=-100,max=100,
                         label='DM Offset (pc/cm^3)'#'$\Delta {\\rm DM}$'
                        ,hidden=hidden)
    
    DMdonebutton = mr.Button(label='Update Filterbanks with New DM',
                             style='primary',
                            hidden=hidden or not ADMINMODE)

#(2) CALIBRATION

hidden = 'Calibration' not in toggle_menu.value 
if not hidden:
    warnings.showwarning = lambda message, category, filename, lineno, file, line : mywarning(message, category, filename, lineno, file, line, polcal.logfile)
    


    hidden = toggle_menu.value != '(ADMIN) Calibration -- Beamform Cal Voltages'

    """polcaldates = []
    for k in parsec.polcal_dict.keys():
        if 'polcal' not in str(k):
            polcaldates.append(str(k))"""
    polcaldate_create_menu = mr.Select(label="Observation Date for New Polarization Calibration Solution ('YYYY-MM-DD'):", 
                                value=parsec.wdict['polcaldate_create_menu'], 
                                choices=[""] + list(parsec.polcaldates)
                               ,hidden=hidden)
    polcopybutton = mr.Button(label='Copy T3 Voltages and Beamformer Weights',
                             style='primary',hidden=hidden)


    #if we want to create new cal solutions from voltage files that are ALREADY COPIED TO H23 choose from here
    #polcalfiles_bf = polcal.get_avail_caldates()
    polcaldate_bf_menu = mr.Select(label="Available Polarization Calibration Dates ('YYYY-MM-DD'):", 
                                value=parsec.wdict['polcaldate_bf_menu'], 
                                choices=[""] + list(parsec.polcalfiles_bf)
                               ,hidden=hidden)


    bfcal_button = mr.Button(label='Run Cal Beamformer',style='primary',hidden=hidden)

    hidden = (toggle_menu.value != '(ADMIN) Calibration -- Make Cal Filterbanks') and (toggle_menu.value != '(ADMIN) Calibration -- Choose Cal Observations')

    polcaldate_findbeams_menu = mr.Select(label="Available Dates With Voltages or Filterbanks on h23 ('YYYY-MM-DD'):", 
                                    value=parsec.wdict['polcaldate_findbeams_menu'],#polcalfiles_findbeams[0], 
                                    choices=list(parsec.polcalfiles_findbeams)
                                   ,hidden=hidden)

    hidden = toggle_menu.value != '(ADMIN) Calibration -- Make Cal Filterbanks'

    findbeams_button = mr.Button(label='Find Beam Numbers',style='primary',hidden=hidden)
    filcalbutton = mr.Button(label='Make Calibrator Filterbanks',style='primary',hidden=hidden)


    refreshlogcalbutton = mr.Button(label='Refresh Log',style='primary',hidden=hidden)

    hidden = toggle_menu.value != '(ADMIN) Calibration -- Choose Cal Observations'
    
    #if we want to make solution from filterbanks
    obs_files,obs_ids = polcal.get_calfil_files('3C48',polcaldate_findbeams_menu.value,'3C48*0')
    #initval = ''
    """if 'cal_name_3C48_center' in parsec.polcal_dict.keys():
        initval = parsec.polcal_dict['cal_name_3C48_center']
    """
    obsid3C48_menu = mr.Select(label="3C48 Cal Observation ID:", 
                                value=parsec.wdict['obsid3C48_menu'], 
                                choices=[""] + list(obs_ids)
                               ,hidden=hidden)
    obs_files,obs_ids = polcal.get_calfil_files('3C286',polcaldate_findbeams_menu.value,'3C286*0')
    #initval = ''
    """if 'cal_name_3C286_center' in parsec.polcal_dict.keys():
        initval = parsec.polcal_dict['cal_name_3C286_center']
    """
    obsid3C286_menu = mr.Select(label="3C286 Cal Observation ID:", 
                                value=parsec.wdict['obsid3C286_menu'], 
                                choices=[""] + list(obs_ids)
                               ,hidden=hidden)
    ParA_display = mr.NumberBox(data=parsec.wdict['ParA_display'], title=r'Parallactic Angle (degrees)')#($^{\circ}$)') 

    saveplotbutton = mr.Button(label='Save Plot',
                             style='primary',
                            hidden=hidden)
    
    hidden = toggle_menu.value != r'(ADMIN) Calibration -- Make Cal Solutions (|gyy|)'#($|g_{yy}|$)'

    peakheight_slider = mr.Slider( 
        value=parsec.wdict['peakheight_slider'],
        min=1, 
        max=10, 
        step=1, 
        label=r'Peak Height'
    ,hidden=hidden)
    peakwidth_slider = mr.Slider( 
        value=parsec.wdict['peakwidth_slider'],
        min=1, 
        max=20, 
        step=1, 
        label=r'Peak Width'
    ,hidden=hidden)
    sfflag =  mr.Checkbox(value=parsec.wdict['sfflag'], label="Savgol Filter",hidden=hidden)
    sf_window_weight_cals = mr.Slider( 
        value=parsec.wdict['sf_window_weight_cals'],
        min=3, 
        max=510, 
        step=2, 
        label=r'Savitsky-Golay Filter Width (samples)'#'$sf_{ww}$'
    ,hidden=hidden)
    sf_order_cals = mr.Slider( 
        value=parsec.wdict['sf_order_cals'],
        min=1, 
        max=10, 
        step=1, 
        label=r'Savitsky-Golay Filter Polynomial Order'#'$sf_{o}$'
    ,hidden=hidden)
    polyfitflag =  mr.Checkbox(value=parsec.wdict['polyfitflag'], label="Fit with Polynomial",hidden=hidden)
    polyfitorder_slider = mr.Slider( 
        value=parsec.wdict['polyfitorder_slider'],
        min=1, 
        max=9, 
        step=1, 
        label=r'Polynomial Fit Order'
    ,hidden=hidden)
    edgefreq_slider = mr.Slider( 
        value=parsec.wdict['edgefreq_slider'],
        min=1311.25000003072, 
        max=1498.75, 
        step=30.4e-3, 
        label=r'Edge Frequency (MHz) Cutoff (for Fitting Piecewise Solution)'
    ,hidden=hidden)
    breakfreq_slider = mr.Slider( 
        value=parsec.wdict['breakfreq_slider'],
        min=1311.25000003072, 
        max=1498.75, 
        step=30.4e-3, 
        label=r'Break Frequency (MHz) Cutoff (for Stitching Piecewise Solution)'
    ,hidden=hidden)



    hidden = toggle_menu.value != r'(ADMIN) Calibration -- Make Cal Solutions (|gxx|/|gyy|)'#($|g_{xx}|/|g_{yy}|$)'
    ratio_peakheight_slider = mr.Slider( 
        value=parsec.wdict['ratio_peakheight_slider'],
        min=1, 
        max=10, 
        step=1, 
        label=r'Peak Height'
    ,hidden=hidden)
    ratio_peakwidth_slider = mr.Slider( 
        value=parsec.wdict['ratio_peakwidth_slider'],
        min=1, 
        max=20, 
        step=1, 
        label=r'Peak Width'
    ,hidden=hidden)
    ratio_sfflag =  mr.Checkbox(value=parsec.wdict['ratio_sfflag'], label="Savgol Filter",hidden=hidden)
    ratio_sf_window_weight_cals = mr.Slider( 
        value=parsec.wdict['ratio_sf_window_weight_cals'],
        min=3, 
        max=510, 
        step=2, 
        label=r'Savitsky-Golay Filter Width (samples)'#$sf_{ww}$'
    ,hidden=hidden)
    ratio_sf_order_cals = mr.Slider( 
        value=parsec.wdict['ratio_sf_order_cals'],
        min=1, 
        max=10, 
        step=1, 
        label=r'Savitsky-Golay Filter Polynomial Order'#r'$sf_{o}$'
    ,hidden=hidden)
    ratio_polyfitflag =  mr.Checkbox(value=parsec.wdict['ratio_polyfitflag'], label="Fit with Polynomial",hidden=hidden)
    ratio_polyfitorder_slider = mr.Slider( 
        value=parsec.wdict['ratio_polyfitorder_slider'],
        min=1, 
        max=9, 
        step=1, 
        label=r'Polynomial Fit Degree'
    ,hidden=hidden)
    ratio_edgefreq_slider = mr.Slider( 
        value=parsec.wdict['ratio_edgefreq_slider'],
        min=1311.25000003072, 
        max=1498.75, 
        step=30.4e-3, 
        label=r'Edge Frequency (MHz) Cutoff (for Fitting Piecewise Solution)'
    ,hidden=hidden)
    ratio_breakfreq_slider = mr.Slider( 
        value=parsec.wdict['ratio_breakfreq_slider'],
        min=1311.25000003072, 
        max=1498.75, 
        step=30.4e-3, 
        label=r'Break Frequency (MHz) Cutoff (for Stitching Piecewise Solution)'
    ,hidden=hidden)


    hidden = toggle_menu.value != r'(ADMIN) Calibration -- Make Cal Solutions (<gxx - <gyy)'#($\angle g_{xx} - \angle g_{yy}$)'
    phase_peakheight_slider = mr.Slider( 
        value=parsec.wdict['phase_peakheight_slider'],
        min=1, 
        max=10, 
        step=1, 
        label=r'Peak Height'
    ,hidden=hidden)
    phase_peakwidth_slider = mr.Slider( 
        value=parsec.wdict['phase_peakwidth_slider'],
        min=1, 
        max=20, 
        step=1, 
        label=r'Peak Width'
    ,hidden=hidden)
    phase_sfflag =  mr.Checkbox(value=parsec.wdict['phase_sfflag'], label="Savgol Filter",hidden=hidden)
    phase_sf_window_weight_cals = mr.Slider( 
        value=parsec.wdict['phase_sf_window_weight_cals'],
        min=3, 
        max=510, 
        step=2, 
        label=r'Savitsky-Golay Filter Width (samples)'#r'$sf_{ww}$'
    ,hidden=hidden)
    phase_sf_order_cals = mr.Slider( 
        value=parsec.wdict['phase_sf_order_cals'],
        min=1, 
        max=10, 
        step=1, 
        label=r'Savitsky-Golay Filter Polynomial Order'#r'$sf_{o}$'
    ,hidden=hidden)
    phase_polyfitflag =  mr.Checkbox(value=parsec.wdict['phase_polyfitflag'], label="Fit with Polynomial",hidden=hidden)
    phase_polyfitorder_slider = mr.Slider( 
        value=parsec.wdict['phase_polyfitorder_slider'],
        min=1, 
        max=9, 
        step=1, 
        label=r'Polynomial Fit Degree'
    ,hidden=hidden)

    savecalsolnbutton = mr.Button(label='Save Cal Solution',
                             style='primary',hidden=hidden)

    hidden = toggle_menu.value != r'(2) Calibration -- Calibrate'
    #if pol cal solution already exists
    #polcalfiles = glob.glob(parsec.default_path + 'POLCAL_PARAMETERS_*csv')
    #polcalfiles = [polcalfiles[i][polcalfiles[i].index('POLCAL'):] for i in range(len(polcalfiles))]
    polcaldate_menu = mr.Select(label="Polarization Calibration File ('YY-MM-DD'):", 
                                value=parsec.wdict['polcaldate_menu'], 
                                choices=[""] + parsec.polcalfiles
                               ,hidden=hidden )
    
    polcalprocs = mr.Numeric(value=parsec.wdict['polcalprocs'], 
                         step=32,
                         min=1,max=128,
                         label='Number of Processes (Use Powers of 2)'
                        ,hidden=hidden or parsec.state_dict['polcaldataloaded'] or not ADMINMODE)
    

    polcalbutton = mr.Button(label='Calibrate',
                             style='primary',hidden=hidden or parsec.state_dict['polcaldataloaded'])

    savepolcalfilbutton = mr.Button(label='Save Calibrated Filterbanks',
                             style='primary',hidden=hidden or not ADMINMODE)

    

    #showlogcal = mr.Checkbox(value=parsec.wdict['showlogcal'], label="Show Pol Cal Log",hidden=hidden)

    hidden = ((toggle_menu.value != r'(2) Calibration -- Calibrate') and
              (toggle_menu.value != r'(ADMIN) Calibration -- Make Cal Solutions (|gyy|)') and #($|g_{yy}|$)') and 
              (toggle_menu.value != r'(ADMIN) Calibration -- Make Cal Solutions (|gxx|/|gyy|)') and #($|g_{xx}|/|g_{yy}|$)') and
              (toggle_menu.value != r'(ADMIN) Calibration -- Make Cal Solutions (<gxx - <gyy)'))#($\angle g_{xx} - \angle g_{yy}$)'))
    saveplotbutton = mr.Button(label='Save Plot',
                             style='primary',
                            hidden=hidden)

#(3) FILTERING
hidden = toggle_menu.value != '(3) Filter Weights'
if not hidden:
    
    warnings.showwarning = lambda message, category, filename, lineno, file, line : mywarning(message, category, filename, lineno, file, line, filt.logfile)
    
    
    MAXCOMPS = 5
    ncomps_num = mr.Numeric(value=parsec.wdict['ncomps_num'], 
                         step=1,
                         min=1,max=MAXCOMPS,
                         label='Number of Resolved Components'
                        ,hidden=hidden)
    comprange_slider = mr.Range(value=parsec.wdict['comprange_slider'],  #ms
                            min=0, 
                            max=parsec.wdict['comprange_slider_max'], 
                            label="Lower and Upper Limit of Component (ms from window start)", 
                            step=32.7e-3
                    ,hidden=hidden or (ncomps_num.value == 1))
    """n_t_slider_filt = mr.Slider( #time downsampling factor
        value=parsec.wdict['n_t_slider_filt'],
        min=1, 
        max=128, 
        step=1, 
        label='$n_t$'
    ,hidden=hidden)
    logn_f_slider_filt = mr.Slider( #freq downsampling factor
        value=parsec.wdict['logn_f_slider_filt'],
        min=0, 
        max=10, 
        step=1, 
        label='${\\rm log_{2}}(n_f)$'
    ,hidden=hidden)"""
    filt_showerrs = mr.Checkbox(value=parsec.wdict['filt_showerrs'], label="Show Errors",hidden=hidden)
    
    multipeaks = mr.Checkbox(value=parsec.wdict['multipeaks'], label="Multiple Peaks",hidden=hidden)
    multipeaks_height_slider = mr.Slider(
        value=parsec.wdict['multipeaks_height_slider'],
        min=0, 
        max=1, 
        step=0.01, 
        label="Minimum Peak Height"
    ,hidden=hidden)

    avger_w_slider = mr.Slider(
        value=parsec.wdict['avger_w_slider'],
        min=1, 
        max=32, 
        step=1, 
        label=r'Downsampling Factor for Weights (ntw)'#r'$n_{tw}$'
    ,hidden=hidden)
    sf_window_weights_slider = mr.Slider(
        value=parsec.wdict['sf_window_weights_slider'],
        min=3, 
        max=33, 
        step=2, 
        label=r'Savitsky Golay-Filter Width (samples)'#r'$sf_{ww}$'
    ,hidden=hidden)
    logibox_slider = mr.Slider(
        value=parsec.wdict['logibox_slider'],
        min=0, 
        max=6, 
        step=1, 
        label=r'log2(ibox)'#r'${\rm log_{2}}({\rm ibox})$'
    ,hidden=hidden)
    """logwindow_slider = mr.Slider(
        value=parsec.wdict['logwindow_slider'],
        min=5, 
        max=9, 
        step=1, 
        label='log2(window)'#r'base ${\rm log_{2}}({\rm window})$'
    ,hidden=hidden)"""

    buff_L_slider = mr.Slider(
        value=parsec.wdict['buff_L_slider'],
        min=1, 
        max=128, 
        step=1, 
        label='left buffer'#r'${\rm buff}_{L}$'
    ,hidden=hidden)
    buff_R_slider = mr.Slider(
        value=parsec.wdict['buff_R_slider'],
        min=1, 
        max=128, 
        step=1, 
        label='right buffer'#r'${\rm buff}_{R}$'
    ,hidden=hidden)

    nextcompbutton = mr.Button(label='Next Component',
                             style='primary',hidden=hidden)

    donecompbutton = mr.Button(label='Done',
                             style='primary',hidden=hidden)

    fluxestbutton = mr.Button(label='Estimate Absolute Flux in Jy',
                             style='primary',hidden=hidden)

    Iflux_display = mr.NumberBox(data=parsec.wdict['Iflux_display'],#parsec.FRB_DM[parsec.FRB_IDS.index(ids)], 
                                    title=r'I (Jy)'
                                   )
    Qflux_display = mr.NumberBox(data=parsec.wdict['Qflux_display'],#parsec.FRB_DM[parsec.FRB_IDS.index(ids)], 
                                    title=r'Q (Jy)'
                                   )
    Uflux_display = mr.NumberBox(data=parsec.wdict['Uflux_display'],#parsec.FRB_DM[parsec.FRB_IDS.index(ids)], 
                                    title=r'U (Jy)'
                                   )
    Vflux_display = mr.NumberBox(data=parsec.wdict['Vflux_display'],#parsec.FRB_DM[parsec.FRB_IDS.index(ids)], 
                                    title=r'V (Jy)'
                                   )
    
    
    
#(4) SCATTERING
#widgets for scattering dashboard
hidden = toggle_menu.value != '(4) Scattering Analysis'
if not hidden:
    
    warnings.showwarning = lambda message, category, filename, lineno, file, line : mywarning(message, category, filename, lineno, file, line, scatscint.logfile)
    
    scattermenu = mr.MultiSelect(label="Resolved Components", 
                              value=parsec.wdict['scattermenu'], 
                              choices=parsec.wdict['scattermenu_choices'],
                                hidden=hidden)

    scatfitmenu = mr.Select(label="Fitting Method",
                            value=parsec.wdict['scatfitmenu'],
                            choices=parsec.wdict['scatfitmenu_choices'],
                            hidden=hidden)
    
    refresh_button = mr.Button(label=r'Refresh from Background Processes',style='primary',hidden=hidden or scatfitmenu.value not in ['Nested Sampling','EMCEE Markov-Chain Monte Carlo'])
    
    scatterbackground = mr.Checkbox(value=parsec.wdict['scatterbackground'],label="Run in Background",hidden=hidden or scatfitmenu.value not in ['Nested Sampling','EMCEE Markov-Chain Monte Carlo'])

    scatterweights = mr.Checkbox(value=parsec.wdict['scatterweights'],label="Weighted Fit",hidden=hidden)
    scatterresume = mr.Checkbox(value=parsec.wdict['scatterresume'],label="Resume Last Run",hidden=hidden or scatfitmenu.value != 'Nested Sampling')
    scattersamps = mr.Checkbox(value=parsec.wdict['scattersamps'],label="Show Samples",hidden=hidden or scatfitmenu.value not in ['Nested Sampling','EMCEE Markov-Chain Monte Carlo'])
    
    
    scatter_nlive = mr.Numeric(value=parsec.wdict['scatter_nlive'], 
                         step=1,
                         min=1,max=1000000,
                         label='Nested Sampling nlive'
                        ,hidden=hidden or scatfitmenu.value != 'Nested Sampling')
    
    scatter_nwalkers = mr.Numeric(value=parsec.wdict['scatter_nwalkers'], 
                         step=1,
                         min=1,max=100,
                         label='MCMC Walkers'
                        ,hidden=hidden or scatfitmenu.value != 'EMCEE Markov-Chain Monte Carlo')
    
    scatter_nsteps = mr.Numeric(value=parsec.wdict['scatter_nsteps'], 
                         step=1,
                         min=2,max=1000000,
                         label='MCMC Steps'
                        ,hidden=hidden or scatfitmenu.value != 'EMCEE Markov-Chain Monte Carlo')
    
    scatter_nburn = mr.Numeric(value=parsec.wdict['scatter_nburn'], 
                         step=1,
                         min=1,max=int(scatter_nsteps.value),
                         label='MCMC Burn-in Samples'
                        ,hidden=hidden or scatfitmenu.value != 'EMCEE Markov-Chain Monte Carlo')
    
    
    scatter_nthin = mr.Numeric(value=parsec.wdict['scatter_nthin'], 
                         step=1,
                         min=1,max=int(scatter_nsteps.value//2),
                         label='MCMC Down-sampling Factor'
                        ,hidden=hidden or scatfitmenu.value != 'EMCEE Markov-Chain Monte Carlo')
    
    scatter_sliderrange = mr.Numeric(value=parsec.wdict['scatter_sliderrange'], 
                         step=0.1,
                         min=0.1,max=1,
                         label='Initial Slider Range'
                        ,hidden=hidden)
    
    #scatter_init = mr.Button(label=r'Reset Sliders to Initial Values',style='primary',hidden=hidden)
    #scatter_init = mr.Checkbox(value=parsec.wdict['scatter_init'],label="Reset Sliders to Initial Values",hidden=hidden)
    
    
    
#(5) SCINTILLATION
hidden = toggle_menu.value != '(5) Scintillation Analysis'
if not hidden:
    warnings.showwarning = lambda message, category, filename, lineno, file, line : mywarning(message, category, filename, lineno, file, line, scatscint.logfile)
    
    #mr.Note("## Scintillation Settings")
    
    scintmenu = mr.Select(label="Resolved Components for Scintillation Bandwidth Fitting", 
                                value=parsec.wdict['scintmenu'], 
                                choices=parsec.wdict['scintmenu_choices'],
                                hidden=hidden)

    scintfitmenu = mr.Select(label="Fitting Method",
                            value=parsec.wdict['scintfitmenu'],
                            choices=parsec.wdict['scintfitmenu_choices'],
                            hidden=hidden)


    gamma_guess = mr.Numeric(value=parsec.wdict['gamma_guess'], 
                         step=1e-3,
                         min=1,max=50,
                         label=r'gamma Initial Guess (MHz)'
                        ,hidden=hidden)
    m_guess = mr.Numeric(value=parsec.wdict['m_guess'], 
                         step=1e-3,
                         min=0,max=1,
                         label=r'm Initial Guess'
                        ,hidden=hidden)
    c_guess = mr.Numeric(value=parsec.wdict['c_guess'], 
                         step=1e-3,
                         min=-1,max=1,
                         label=r'c Initial Guess'
                        ,hidden=hidden)
    scint_fit_range = mr.Numeric(value=np.nanmax([2*parsec.state_dict['n_f']*parsec.state_dict['base_df']/1e6,parsec.wdict['scint_fit_range']]),
                                min=2*parsec.state_dict['n_f']*parsec.state_dict['base_df']/1e6,max=185,
                                step=1,label='Fit Range (MHz)',
                                hidden=hidden)

    calc_bw_button = mr.Button(label='Calculate Scintillation Bandwidth',
                             style='primary',hidden=hidden)
    save_scint_button = mr.Button(label='Save To File',style='primary',hidden=hidden)
    
    #mr.Note("## Spectral Index Settings")
    
    specidxmenu = mr.Select(label="Resolved Components for Spectral Index Fitting", 
                                value=parsec.wdict['specidxmenu'], 
                                choices=parsec.wdict['specidxmenu_choices'],
                                hidden=hidden)

    specidxfitmenu = mr.Select(label="Fitting Method",
                            value=parsec.wdict['specidxfitmenu'],
                            choices=parsec.wdict['specidxfitmenu_choices'],
                            hidden=hidden)


    specidx_guess = mr.Numeric(value=parsec.wdict['specidx_guess'], 
                         step=1e-3,
                         min=-10,max=10,
                         label=r'Gamma Initial Guess'
                        ,hidden=hidden)
    F0_guess = mr.Numeric(value=parsec.wdict['F0_guess'], 
                         step=1e-3,
                         min=0,max=1000,
                         label=r'F0 Initial Guess'
                        ,hidden=hidden)

    calc_specidx_button = mr.Button(label='Calculate Spectral Index',
                             style='primary',hidden=hidden)
    save_specidx_button = mr.Button(label='Save To File',style='primary',hidden=hidden)
    
    
#(6) RM ANALYSIS

#widgets for filter weights dashboard
hidden = toggle_menu.value != '(6) RM Synthesis'

if not hidden:
    def mywarning(message, category, filename, lineno, file=None, line=None):
        warning_file = open(RMcal.logfile, "a")
        warning_file.write(warnings.formatwarning(message, category, filename, lineno, line))
        warning_file.close()

    warnings.showwarning = mywarning
    
    getRMgal_button = mr.Button(label=r'Get Galactic RM',
                               style='primary',hidden=hidden)
    getRMion_button = mr.Button(label=r'Get Ionospheric RM',
                               style='primary',hidden=hidden)



    #display results for single component at a time
    rmcomp_menu = mr.Select(label="Component:", 
                                value=parsec.wdict['rmcomp_menu'],
                                choices=parsec.wdict['rmcomp_menu_choices'],
                                hidden=hidden)#frbfiles[0], choices=frbfiles,hidden=hidden)


    useRMTools = mr.Checkbox(value=parsec.wdict['useRMTools'], label="RM-Tools",hidden=hidden)
    maxRM_num_tools = mr.Numeric(value=parsec.wdict['maxRM_num_tools'], 
                         step=1,
                         min=1e2,max=1e6,
                         label=r'Maximum Trial RM (rad/m^2)'
                        ,hidden=hidden or not useRMTools.value)
    dRM_tools = mr.Numeric(value=parsec.wdict['dRM_tools'], 
                         step=10,
                         min=200,max=int(2e6),
                         label='Spacing of RM-Tools Trials'
                        ,hidden=hidden or not useRMTools.value)


    useRMsynth = mr.Checkbox(value=parsec.wdict['useRMsynth'], label="1D RM Synthesis",hidden=hidden)

    
    nRM_num = mr.Numeric(value=parsec.wdict['nRM_num'], 
                         step=1,
                         min=10,max=int(2e6),
                         label='Number of RM Trials'
                        ,hidden=hidden or not useRMsynth.value)

    minRM_num = mr.Numeric(value=parsec.wdict['minRM_num'], 
                         step=1,
                         min=-1e6,max=parsec.wdict['maxRM_num'],
                         label=r'Minimum Trial RM (rad/m^2)'
                        ,hidden=hidden or not useRMsynth.value)

    maxRM_num = mr.Numeric(value=np.clip(parsec.wdict['maxRM_num'],minRM_num.value,1e6), 
                         step=1,
                         min=minRM_num.value,max=1e6,
                         label=r'Maximum Trial RM (rad/m^2)'
                        ,hidden=hidden or not useRMsynth.value)
    getRMbutton = mr.Button(label='Run Initial RM Synthesis',
                             style='primary',hidden=hidden or (not useRMsynth.value and not useRMTools.value))

    #condition that initial RM synth not used yet
    conditioninitRM = ((rmcomp_menu.value == 'All' and (~np.isnan(parsec.state_dict["RMcalibrated"]["RM2"][0]) or
                                          ~np.isnan(parsec.state_dict["RMcalibrated"]["RM1"][0]) or
                                          ~np.isnan(parsec.state_dict["RMcalibrated"]["RM_tools"][0]))) or
        (rmcomp_menu.value != 'All' and rmcomp_menu.value != '' and (~np.isnan(parsec.state_dict['comps'][int(rmcomp_menu.value)]["RMcalibrated"]["RM2"][0]) or
                                                                     ~np.isnan(parsec.state_dict['comps'][int(rmcomp_menu.value)]["RMcalibrated"]["RM1"][0]) or
                                                                     ~np.isnan(parsec.state_dict['comps'][int(rmcomp_menu.value)]["RMcalibrated"]["RM_tools"][0]))))
    
    useRM2D = mr.Checkbox(value=parsec.wdict['useRM2D'], label="2D RM Synthesis (S/N Method)",
                          hidden=hidden)
    if (useRM2D.value and not conditioninitRM): printRM2Dwarning = True
    else: printRM2Dwarning = False
        
    nRM_num_zoom = mr.Numeric(value=parsec.wdict['nRM_num_zoom'], 
                         step=1,
                         min=10,max=int(2e6),
                         label='Number of RM Trials (Zoom around Peak)'
                        ,hidden=hidden or (not useRM2D.value and not useRMsynth.value))

    RM_window_zoom = mr.Numeric(value=parsec.wdict['RM_window_zoom'], 
                         step=1,
                         min=10,max=int(1e6),
                         label='RM Window (Zoom around Peak)'
                        ,hidden=hidden or  (not useRM2D.value and not useRMsynth.value and not useRMTools.value))

    dRM_tools_zoom = mr.Numeric(value=parsec.wdict['dRM_tools_zoom'], 
                         step=10,
                         min=0.4,max=1000.4,
                         label='Spacing of RM-Tools Trials (Zoom around 0)'
                        ,hidden=hidden or  (not useRMTools.value))

    getRMbutton_zoom = mr.Button(label='Run Zoom RM Synthesis',
                             style='primary',
                            hidden=hidden or (not useRM2D.value and not useRMsynth.value and not useRMTools.value))
    RMsynthbackground = mr.Checkbox(value=parsec.wdict['RMsynthbackground'],
                                    label="Run in Background",hidden=hidden or (not useRMsynth.value and not useRM2D.value))
    refresh_button = mr.Button(label=r'Refresh from Background Processes',style='primary',
                               hidden=hidden or (not RMsynthbackground.value))

    maxthreads = mr.Numeric(value=parsec.wdict['maxthreads'], 
                         step=1,
                         min=1,max=100,
                         label='Maximum Number of Threads'
                        ,hidden=hidden or (not useRM2D.value and not useRMsynth.value) or (not ADMINMODE))
    maxbatches = mr.Numeric(value=parsec.wdict['maxbatches'], 
                         step=1,
                         min=1,max=100,
                         label='Maximum Number of Batches'
                        ,hidden=hidden or (not useRM2D.value and not useRMsynth.value) or (not ADMINMODE))
    maxtrials_per_thread = mr.Numeric(value=parsec.wdict['maxtrials'], 
                         step=1,
                         min=1,max=1000,
                         label='Maximum Number of Trials per Thread'
                        ,hidden=hidden or (not useRM2D.value and not useRMsynth.value) or (not ADMINMODE))
    #galactic, ionospheric RM

    RM_gal_display = mr.NumberBox(data=parsec.wdict['RM_gal_display'],#parsec.FRB_DM[parsec.FRB_IDS.index(ids)], 
                                    title=r'RMgal (rad/m^2)'
                                   )
    RM_galerr_display = mr.NumberBox(data=parsec.wdict['RM_galerr_display'], 
                                  title=r'RMgal Error (rad/m^2)'
                                 )


    RM_ion_display = mr.NumberBox(data=parsec.wdict['RM_ion_display'],#parsec.FRB_DM[parsec.FRB_IDS.index(ids)], 
                                    title=r'RMion (rad/m^2)'
                                   )
    RM_ionerr_display = mr.NumberBox(data=parsec.wdict['RM_ionerr_display'], 
                                  title=r'RMion Error (rad/m^2)'
                                 )

    #measured RM

    RMdisplay = mr.NumberBox(data=parsec.wdict['RMdisplay'],#parsec.FRB_DM[parsec.FRB_IDS.index(ids)], 
                                    title=r'RM (rad/m^2)'
                                   )
    RMerrdisplay = mr.NumberBox(data=parsec.wdict['RMerrdisplay'], 
                                  title=r'RM Error (rad/m^2)'
                                 )
else: 
    RM_gal_display = None
    RM_galerr_display = None
    RM_ion_display = None
    RM_ionerr_display = None
    RMdisplay = None
    RMerrdisplay = None

    
# (7) RM/DM Budget screen
hidden = toggle_menu.value != '(7) RM, DM, Bfield Budget'
if not hidden:
    trialz = mr.Numeric(value=parsec.wdict['trialz'], 
                     step=1e-3,
                     min=-1,max=10,
                     label='Trial Redshift z'
                    ,hidden=hidden)
    
    catalog_selection = mr.MultiSelect(label="Select Catalogs to Query (Leave Blank to Query All)", 
                          value=parsec.wdict['catalog_selection'], 
                          choices=parsec.wdict['catalog_selection_choices'],
                           hidden=hidden)
    
    galtype_selection =  mr.MultiSelect(label="Select Galaxy Types to Query (Leave Blank to Query All)", 
                          value=parsec.wdict['galtype_selection'], 
                          choices=parsec.wdict['galtype_selection_choices'],
                           hidden=hidden)
    
    queryradius = mr.Numeric(value=parsec.wdict['queryradius'], 
                     step=1/60,
                     min=1/60,max=30*60,
                     label='Query Search Radius (arcmin)'
                    ,hidden=hidden)
    
    limitzrange = mr.Checkbox(value=parsec.wdict['limitzrange'], 
                              label="Query Redshift Range",hidden=hidden)
    zrange = mr.Numeric(value=parsec.wdict['zrange'], 
                     step=1e-4,
                     min=1e-4,max=np.abs(parsec.wdict['trialz']),
                     label=r'Redshift Range'
                    ,hidden=hidden)
    
    cosmo_selection = mr.Select(label='Select Cosmology Model',
                              value=parsec.wdict['cosmo_selection'],
                              choices=parsec.wdict['cosmo_selection_choices'],
                              hidden=hidden)
    runquerybutton = mr.Button(label='Run SIMBAD Query',
                             style='primary',
                              hidden=hidden)
    
    

#(7) POLARIZATION ANALYSIS
hidden = toggle_menu.value != '(8) Polarization Analysis'
if not hidden:
    warnings.showwarning = lambda message, category, filename, lineno, file, line : mywarning(message, category, filename, lineno, file, line, dsapol.logfile)
    
    showghostPA = mr.Checkbox(value=parsec.wdict['showghostPA'], label="Show PA with Linear S/N < 3",hidden=hidden)
    showpolfracs = mr.Checkbox(value=parsec.wdict['showpolfracs'], label="Show Polarization Fraction",hidden=hidden)

    #choose which component to analyze


    polcomp_menu = mr.Select(label="Update Bounds for Component:", 
                                value=parsec.wdict['polcomp_menu'],
                                choices=parsec.wdict['polcomp_menu_choices'],
                                hidden=hidden)#frbfiles[0], choices=frbfiles,hidden=hidden)


    intLbuffer_slider = mr.Slider(
        value=parsec.wdict['intLbuffer_slider'],
        min=-10, 
        max=10, 
        step=1, 
        label=r'left buffer offset'
    ,hidden=hidden)

    intRbuffer_slider = mr.Slider(
        value=parsec.wdict['intRbuffer_slider'],
        min=-10, 
        max=10, 
        step=1, 
        label=r'right buffer offset'
    ,hidden=hidden)
    saveplotbutton = mr.Button(label='Save Plot',
                             style='primary',
                            hidden=hidden)



#(8) ARCHIVE
#widgets for pol analysis dashboard
hidden = (toggle_menu.value != '(9) Archive Data') 
if not hidden:
    warnings.showwarning = lambda message, category, filename, lineno, file, line : mywarning(message, category, filename, lineno, file, line, rmtablefuncs.logfile)
    overwritefils = mr.Checkbox(value=parsec.wdict['overwritefils'], label="Overwrite Calibrated Filterbanks",
                                hidden=hidden or not ADMINMODE)

    savebutton = mr.Button(label='Save Data to Level 3',
                             style='primary',
                              hidden=hidden or not ADMINMODE)

    archivepolcalbutton = mr.Button(label='Archive Pol Calibration Voltages to dsastorage',
                             style='primary',
                             hidden=hidden or not ADMINMODE)

    archivebutton = mr.Button(label='Archive FRB Filterbanks and Tables to dsastorage',
                             style='primary',
                             hidden=hidden or not ADMINMODE)

    notesinput = mr.Text(value=parsec.wdict['notesinput'], label="Notes for Spreadsheet", rows=5,hidden=hidden)
    spreadsheetbutton = mr.Button(label='Save .csv for Spreadsheet',
                             style='primary',
                              hidden=hidden)

    txtfilebutton = mr.Button(label='Save .txt Summary',
                             style='primary',
                              hidden=hidden)
# Out:
# mercury.Checkbox
# mercury.Checkbox
# mercury.Select
# mercury.Slider
# mercury.Slider
# mercury.Button

# %%
nbox = None
#(ADMIN) MAKE FILS
hidden = toggle_menu.value != '(ADMIN) Make Filterbanks'
if not hidden:
    #Slide Title
    mr.Markdown("### (ADMIN) Make Filterbanks")
    
    #main screen
    nbox = None
    try:

        nbox = parsec.ADMIN_makefil_screen(frbfiles_menu,
                                RA_display,DEC_display,DM_init_display,ibeam_display,ibox_display,
                                mjd_display,z_display,updatebutton,filbutton)
    except KeyError as ex:
        print("Preceding Stages Required")

#(0) LOAD DATA
hidden = toggle_menu.value != '(0) Load Data'
if not hidden:
    #Slide Title
    mr.Markdown("### (0) Load Data")
    
    #main screen
    nbox = None
    try:

        nbox = parsec.load_screen(frbfiles_menu,n_t_slider,logn_f_slider,
                                RA_display,DEC_display,DM_init_display,ibeam_display,ibox_display,
                                mjd_display,z_display,loadbutton,polcalloadbutton)
    except KeyError as ex:
        print("Preceding Stages Required")

    
#(1) DEDISPERSION

hidden=toggle_menu.value != '(1) Dedispersion Tuning'
if not hidden:
    # slide title
    mr.Markdown("### (1) Dedispersion Tuning")
    
    
    try:
    
        #updateDMbutton = mr.Button(label='Update DM and Filterbanks',
        #                         style='primary',
        #                        hidden=hidden)
        #updateDM = mr.Checkbox(value=parsec.wdict['updateDM'], label="Update DM and Filterbanks when Confirmed",hidden=hidden)
    
        DM_showerrs = mr.Checkbox(value=parsec.wdict['DM_showerrs'], label="Show Errors",hidden=hidden)
    
        saveplotbutton = mr.Button(label='Save Plot',
                                 style='primary',
                                hidden=hidden)
    
        parsec.dedisp_screen(n_t_slider,logn_f_slider,logwindow_slider,ddm_num,
                             DMdonebutton,saveplotbutton,DM_showerrs)

    except KeyError as ex:
        print("Preceding Stages Required")
        
#(2) CALIBRATION


hidden = ('Calibration' not in toggle_menu.value ) or (not ADMINMODE)
if not hidden:
    
    mr.Markdown("### (2) Calibration")
    
    mr.Markdown(" Observation Beams:")
    #if parsec.state_dict["current_state"] >= parsec.state_map['polcal']:
    try:
        beam_dict_3C48,beam_dict_3C286 = parsec.polcal_screen(polcaldate_menu,polcaldate_create_menu,polcaldate_bf_menu,polcaldate_findbeams_menu,obsid3C48_menu,obsid3C286_menu,
                                                         polcalbutton,polcopybutton,bfcal_button,findbeams_button,filcalbutton,ParA_display,
                                                         edgefreq_slider,breakfreq_slider,sf_window_weight_cals,sf_order_cals,peakheight_slider,peakwidth_slider,polyfitorder_slider,
                                                         ratio_edgefreq_slider,ratio_breakfreq_slider,ratio_sf_window_weight_cals,ratio_sf_order_cals,ratio_peakheight_slider,ratio_peakwidth_slider,ratio_polyfitorder_slider,
                                                         phase_sf_window_weight_cals,phase_sf_order_cals,phase_peakheight_slider,phase_peakwidth_slider,phase_polyfitorder_slider,savecalsolnbutton,
                                                         sfflag,polyfitflag,ratio_sfflag,ratio_polyfitflag,phase_sfflag,phase_polyfitflag,saveplotbutton,polcalprocs,savepolcalfilbutton)
    except KeyError as ex:
        print("Preceding Stages Required")
        

hidden = (toggle_menu.value != '(2) Calibration -- Calibrate') or ADMINMODE
if not hidden:
    
    
    mr.Markdown("### (2) Calibration" + str(": Pol Calibrated Filterbanks have been loaded, so the Calibrate function is not available." if parsec.state_dict['polcaldataloaded'] else ""))
    try:
        nbox = parsec.polcal_screen_USER(polcaldate_menu,polcalbutton,ParA_display,saveplotbutton,polcalprocs)
    except KeyError as ex:
        print("Preceding Stages Required")
        

        
#(3) FILTERING
hidden = toggle_menu.value != '(3) Filter Weights'
if not hidden:
    mr.Markdown("### (3) Filter Weights")
    try:
        parsec.filter_screen(logwindow_slider,logibox_slider,
                         buff_L_slider,buff_R_slider,ncomps_num,comprange_slider,nextcompbutton,donecompbutton,
                        avger_w_slider,sf_window_weights_slider,multipeaks,multipeaks_height_slider,fluxestbutton,
                            Iflux_display,Qflux_display,Uflux_display,Vflux_display,filt_showerrs)
    except KeyError as ex:
        print("Preceding Stages Required")
    
#(4) SCATTERING
#widgets for scattering dashboard
hidden = toggle_menu.value != '(4) Scattering Analysis'
if not hidden:
    mr.Markdown("### (4) Scattering Analysis")
    
    if parsec.state_dict['window'] != 2**logwindow_slider.value:
        parsec.state_dict['scatter_init'] = False
        for i in range(parsec.state_dict['n_comps']):
            parsec.scatter_reset_initvals(i,scatter_sliderrange.value,window=int(2**logwindow_slider.value))
        for i in range(parsec.state_dict['n_comps'],5):
            parsec.scatter_reset_initvals(i,scatter_sliderrange.value,window=int(2**logwindow_slider.value),nocomp=True)
    
    
    x0_guess_comps = []
    amp_guess_comps = []
    sigma_guess_comps = []
    tau_guess_comps = []
    
    x0_range_sliders = []
    amp_range_sliders = []
    sigma_range_sliders = []
    tau_range_sliders = []
    
    hiddens = []

    #comp 0
    hiddens.append(hidden | ('Component 0' not in scattermenu.value))
    #if not hiddens[0]:
    #    note_0 = mr.Note('Component 0')         
    x0_guess_0 = mr.Numeric(value=parsec.wdict['x0_guess_0'], 
                 step=32.7e-3,
                 min=np.around(parsec.state_dict['time_axis'][parsec.state_dict['timestart']-int(2**logwindow_slider.value)]*1e-3,2),#x0_guess_0.value*(1 - scatter_sliderrange.value), 
                            max=np.around(parsec.state_dict['time_axis'][parsec.state_dict['timestop']+int(2**logwindow_slider.value)]*1e-3,2),#x0_guess_0.value*(1 + scatter_sliderrange.value), 
                            label=r'(Comp 0) x0 Initial Guess (ms)'
                ,hidden=hiddens[0])
    x0_range_0 = mr.Range(value=parsec.wdict['x0_range_0'],  #ms
                            min=np.around(parsec.state_dict['time_axis'][parsec.state_dict['timestart']-int(2**logwindow_slider.value)]*1e-3,2),#x0_guess_0.value*(1 - scatter_sliderrange.value), 
                            max=np.around(parsec.state_dict['time_axis'][parsec.state_dict['timestop']+int(2**logwindow_slider.value)]*1e-3,2),#x0_guess_0.value*(1 + scatter_sliderrange.value), 
                            label=r'(Comp 0) x0 Search Range (ms)', 
                            step=32.7e-3
                    ,hidden=hiddens[0])
    if not hiddens[0]:
        x0_guess_comps.append(x0_guess_0)
        x0_range_sliders.append(x0_range_0)
        
    amp_guess_0 = mr.Numeric(value=parsec.wdict['amp_guess_0'], 
                         step=1e-3,
                         min=0,max=500,
                         label=r'(Comp 0) Amplitude Initial Guess'
                        ,hidden=hiddens[0])
    amp_range_0 = mr.Range(value=parsec.wdict['amp_range_0'],  #ms
                            min=0,#amp_guess_0.value*(1 - scatter_sliderrange.value), 
                            max=500,#amp_guess_0.value*(1 + scatter_sliderrange.value), 
                            label=r'(Comp 0) Amplitude Search Range', 
                            step=1e-3
                    ,hidden=hiddens[0])
    if not hiddens[0]:
        amp_guess_comps.append(amp_guess_0)
        amp_range_sliders.append(amp_range_0)

    sigma_guess_0 = mr.Numeric(value=parsec.wdict['sigma_guess_0'], 
                         step=1e-3,
                         min=0,#x0_guess_0.value*(1 - scatter_sliderrange.value), 
                            max=np.around((parsec.state_dict['time_axis'][parsec.state_dict['timestop']+int(2**logwindow_slider.value)] -
                                 parsec.state_dict['time_axis'][parsec.state_dict['timestart']-int(2**logwindow_slider.value)])*1e-3,2),#x0_guess_0.value*(1 + scatter_sliderrange.value), 
                            label=r'(Comp 0) sigma Initial Guess (ms)'
                        ,hidden=hiddens[0])
    sigma_range_0 = mr.Range(value=parsec.wdict['sigma_range_0'],  #ms
                            min=0,#x0_guess_0.value*(1 - scatter_sliderrange.value), 
                            max=np.around((parsec.state_dict['time_axis'][parsec.state_dict['timestop']+int(2**logwindow_slider.value)] -
                                 parsec.state_dict['time_axis'][parsec.state_dict['timestart']-int(2**logwindow_slider.value)])*1e-3,2),#x0_guess_0.value*(1 + scatter_sliderrange.value), 
                            label=r'(Comp 0) sigma Search Range (ms)', 
                            step=1e-3
                    ,hidden=hiddens[0])
    if not hiddens[0]:
        sigma_guess_comps.append(sigma_guess_0)
        sigma_range_sliders.append(sigma_range_0)

    tau_guess_0 = mr.Numeric(value=parsec.wdict['tau_guess_0'], 
                         step=1e-3,
                         min=0,#x0_guess_0.value*(1 - scatter_sliderrange.value), 
                            max=np.around((parsec.state_dict['time_axis'][parsec.state_dict['timestop']+int(2**logwindow_slider.value)] -
                                 parsec.state_dict['time_axis'][parsec.state_dict['timestart']-int(2**logwindow_slider.value)])*1e-3,2),#x0_guess_0.value*(1 + scatter_sliderrange.value), 
                            label=r'(Comp 0) tau Search Range (ms)'
                        ,hidden=hiddens[0])
    tau_range_0 = mr.Range(value=parsec.wdict['tau_range_0'],  #ms
                            min=0,#x0_guess_0.value*(1 - scatter_sliderrange.value), 
                            max=np.around((parsec.state_dict['time_axis'][parsec.state_dict['timestop']+int(2**logwindow_slider.value)] -
                                 parsec.state_dict['time_axis'][parsec.state_dict['timestart']-int(2**logwindow_slider.value)])*1e-3,2),#x0_guess_0.value*(1 + scatter_sliderrange.value), 
                            label=r'(Comp 0) tau Search Range (ms)', 
                            step=1e-3
                    ,hidden=hiddens[0])
    if not hiddens[0]:
        tau_guess_comps.append(tau_guess_0)
        tau_range_sliders.append(tau_range_0)
        
        
        
    #comp 1
    hiddens.append(hidden | ('Component 1' not in scattermenu.value))
    #if not hiddens[0]:
    #    note_0 = mr.Note('Component 0')         
    x0_guess_1 = mr.Numeric(value=parsec.wdict['x0_guess_1'], 
                 step=32.7e-3,
                 min=np.around(parsec.state_dict['time_axis'][parsec.state_dict['timestart']-int(2**logwindow_slider.value)]*1e-3,2),#x0_guess_0.value*(1 - scatter_sliderrange.value), 
                            max=np.around(parsec.state_dict['time_axis'][parsec.state_dict['timestop']+int(2**logwindow_slider.value)]*1e-3,2),#x0_guess_0.value*(1 + scatter_sliderrange.value), 
                            label=r'(Comp 1) x0 Initial Guess (ms)'
                ,hidden=hiddens[1])
    x0_range_1 = mr.Range(value=parsec.wdict['x0_range_1'],  #ms
                            min=np.around(parsec.state_dict['time_axis'][parsec.state_dict['timestart']-int(2**logwindow_slider.value)]*1e-3,2),#x0_guess_0.value*(1 - scatter_sliderrange.value), 
                            max=np.around(parsec.state_dict['time_axis'][parsec.state_dict['timestop']+int(2**logwindow_slider.value)]*1e-3,2),#x0_guess_0.value*(1 + scatter_sliderrange.value), 
                            label=r'(Comp 1) x0 Search Range (ms)', 
                            step=32.7e-3
                    ,hidden=hiddens[1])
    if not hiddens[1]:
        x0_guess_comps.append(x0_guess_1)
        x0_range_sliders.append(x0_range_1)
        
    amp_guess_1 = mr.Numeric(value=parsec.wdict['amp_guess_1'], 
                         step=1e-3,
                         min=0,max=500,
                         label=r'(Comp 1) Amplitude Initial Guess'
                        ,hidden=hiddens[1])
    amp_range_1 = mr.Range(value=parsec.wdict['amp_range_1'],  #ms
                            min=0,#amp_guess_0.value*(1 - scatter_sliderrange.value), 
                            max=500,#amp_guess_0.value*(1 + scatter_sliderrange.value), 
                            label=r'(Comp 1) Amplitude Search Range', 
                            step=1e-3
                    ,hidden=hiddens[1])
    if not hiddens[1]:
        amp_guess_comps.append(amp_guess_1)
        amp_range_sliders.append(amp_range_1)

    sigma_guess_1 = mr.Numeric(value=parsec.wdict['sigma_guess_1'], 
                         step=1e-3,
                         min=0,#x0_guess_0.value*(1 - scatter_sliderrange.value), 
                            max=np.around((parsec.state_dict['time_axis'][parsec.state_dict['timestop']+int(2**logwindow_slider.value)] -
                                 parsec.state_dict['time_axis'][parsec.state_dict['timestart']-int(2**logwindow_slider.value)])*1e-3,2),#x0_guess_0.value*(1 + scatter_sliderrange.value), 
                            label=r'(Comp 1) sigma Initial Guess (ms)'
                        ,hidden=hiddens[1])
    sigma_range_1 = mr.Range(value=parsec.wdict['sigma_range_1'],  #ms
                            min=0,#x0_guess_0.value*(1 - scatter_sliderrange.value), 
                            max=np.around((parsec.state_dict['time_axis'][parsec.state_dict['timestop']+int(2**logwindow_slider.value)] -
                                 parsec.state_dict['time_axis'][parsec.state_dict['timestart']-int(2**logwindow_slider.value)])*1e-3,2),#x0_guess_0.value*(1 + scatter_sliderrange.value), 
                            label=r'(Comp 1) sigma Search Range (ms)', 
                            step=1e-3
                    ,hidden=hiddens[1])
    if not hiddens[1]:
        sigma_guess_comps.append(sigma_guess_1)
        sigma_range_sliders.append(sigma_range_1)

    tau_guess_1 = mr.Numeric(value=parsec.wdict['tau_guess_1'], 
                         step=1e-3,
                         min=0,#x0_guess_0.value*(1 - scatter_sliderrange.value), 
                            max=np.around((parsec.state_dict['time_axis'][parsec.state_dict['timestop']+int(2**logwindow_slider.value)] -
                                 parsec.state_dict['time_axis'][parsec.state_dict['timestart']-int(2**logwindow_slider.value)])*1e-3,2),#x0_guess_0.value*(1 + scatter_sliderrange.value), 
                            label=r'(Comp 1) tau Search Range (ms)'
                        ,hidden=hiddens[1])
    tau_range_1 = mr.Range(value=parsec.wdict['tau_range_1'],  #ms
                            min=0,#x0_guess_0.value*(1 - scatter_sliderrange.value), 
                            max=np.around((parsec.state_dict['time_axis'][parsec.state_dict['timestop']+int(2**logwindow_slider.value)] -
                                 parsec.state_dict['time_axis'][parsec.state_dict['timestart']-int(2**logwindow_slider.value)])*1e-3,2),#x0_guess_0.value*(1 + scatter_sliderrange.value), 
                            label=r'(Comp 1) tau Search Range (ms)', 
                            step=1e-3
                    ,hidden=hiddens[1])
    if not hiddens[1]:
        tau_guess_comps.append(tau_guess_1)
        tau_range_sliders.append(tau_range_1)
        
        
    #comp 2
    hiddens.append(hidden | ('Component 2' not in scattermenu.value))
    #if not hiddens[0]:
    #    note_0 = mr.Note('Component 0')         
    x0_guess_2 = mr.Numeric(value=parsec.wdict['x0_guess_2'], 
                 step=32.7e-3,
                 min=np.around(parsec.state_dict['time_axis'][parsec.state_dict['timestart']-int(2**logwindow_slider.value)]*1e-3,2),#x0_guess_0.value*(1 - scatter_sliderrange.value), 
                            max=np.around(parsec.state_dict['time_axis'][parsec.state_dict['timestop']+int(2**logwindow_slider.value)]*1e-3,2),#x0_guess_0.value*(1 + scatter_sliderrange.value), 
                            label=r'(Comp 2) x0 Initial Guess (ms)'
                ,hidden=hiddens[2])
    x0_range_2 = mr.Range(value=parsec.wdict['x0_range_2'],  #ms
                            min=np.around(parsec.state_dict['time_axis'][parsec.state_dict['timestart']-int(2**logwindow_slider.value)]*1e-3,2),#x0_guess_0.value*(1 - scatter_sliderrange.value), 
                            max=np.around(parsec.state_dict['time_axis'][parsec.state_dict['timestop']+int(2**logwindow_slider.value)]*1e-3,2),#x0_guess_0.value*(1 + scatter_sliderrange.value), 
                            label=r'(Comp 2) x0 Search Range (ms)', 
                            step=32.7e-3
                    ,hidden=hiddens[2])
    if not hiddens[2]:
        x0_guess_comps.append(x0_guess_2)
        x0_range_sliders.append(x0_range_2)
        
    amp_guess_2 = mr.Numeric(value=parsec.wdict['amp_guess_2'], 
                         step=1e-3,
                         min=0,max=500,
                         label=r'(Comp 2) Amplitude Initial Guess'
                        ,hidden=hiddens[2])
    amp_range_2 = mr.Range(value=parsec.wdict['amp_range_2'],  #ms
                            min=0,#amp_guess_0.value*(1 - scatter_sliderrange.value), 
                            max=500,#amp_guess_0.value*(1 + scatter_sliderrange.value), 
                            label=r'(Comp 2) Amplitude Search Range', 
                            step=1e-3
                    ,hidden=hiddens[2])
    if not hiddens[2]:
        amp_guess_comps.append(amp_guess_2)
        amp_range_sliders.append(amp_range_2)

    sigma_guess_2 = mr.Numeric(value=parsec.wdict['sigma_guess_2'], 
                         step=1e-3,
                         min=0,#x0_guess_0.value*(1 - scatter_sliderrange.value), 
                            max=np.around((parsec.state_dict['time_axis'][parsec.state_dict['timestop']+int(2**logwindow_slider.value)] -
                                 parsec.state_dict['time_axis'][parsec.state_dict['timestart']-int(2**logwindow_slider.value)])*1e-3,2),#x0_guess_0.value*(1 + scatter_sliderrange.value), 
                            label=r'(Comp 2) sigma Initial Guess (ms)'
                        ,hidden=hiddens[2])
    sigma_range_2 = mr.Range(value=parsec.wdict['sigma_range_2'],  #ms
                            min=0,#x0_guess_0.value*(1 - scatter_sliderrange.value), 
                            max=np.around((parsec.state_dict['time_axis'][parsec.state_dict['timestop']+int(2**logwindow_slider.value)] -
                                 parsec.state_dict['time_axis'][parsec.state_dict['timestart']-int(2**logwindow_slider.value)])*1e-3,2),#x0_guess_0.value*(1 + scatter_sliderrange.value), 
                            label=r'(Comp 2) sigma Search Range (ms)', 
                            step=1e-3
                    ,hidden=hiddens[2])
    if not hiddens[2]:
        sigma_guess_comps.append(sigma_guess_2)
        sigma_range_sliders.append(sigma_range_2)

    tau_guess_2 = mr.Numeric(value=parsec.wdict['tau_guess_2'], 
                         step=1e-3,
                         min=0,#x0_guess_0.value*(1 - scatter_sliderrange.value), 
                            max=np.around((parsec.state_dict['time_axis'][parsec.state_dict['timestop']+int(2**logwindow_slider.value)] -
                                 parsec.state_dict['time_axis'][parsec.state_dict['timestart']-int(2**logwindow_slider.value)])*1e-3,2),#x0_guess_0.value*(1 + scatter_sliderrange.value), 
                            label=r'(Comp 2) tau Search Range (ms)'
                        ,hidden=hiddens[2])
    tau_range_2 = mr.Range(value=parsec.wdict['tau_range_2'],  #ms
                            min=0,#x0_guess_0.value*(1 - scatter_sliderrange.value), 
                            max=np.around((parsec.state_dict['time_axis'][parsec.state_dict['timestop']+int(2**logwindow_slider.value)] -
                                 parsec.state_dict['time_axis'][parsec.state_dict['timestart']-int(2**logwindow_slider.value)])*1e-3,2),#x0_guess_0.value*(1 + scatter_sliderrange.value), 
                            label=r'(Comp 2) tau Search Range (ms)', 
                            step=1e-3
                    ,hidden=hiddens[2])
    if not hiddens[2]:
        tau_guess_comps.append(tau_guess_2)
        tau_range_sliders.append(tau_range_2)
        
    #comp 3
    hiddens.append(hidden | ('Component 3' not in scattermenu.value))
    #if not hiddens[0]:
    #    note_0 = mr.Note('Component 0')         
    x0_guess_3 = mr.Numeric(value=parsec.wdict['x0_guess_3'], 
                 step=32.7e-3,
                 min=np.around(parsec.state_dict['time_axis'][parsec.state_dict['timestart']-int(2**logwindow_slider.value)]*1e-3,2),#x0_guess_0.value*(1 - scatter_sliderrange.value), 
                            max=np.around(parsec.state_dict['time_axis'][parsec.state_dict['timestop']+int(2**logwindow_slider.value)]*1e-3,2),#x0_guess_0.value*(1 + scatter_sliderrange.value), 
                            label=r'(Comp 3) x0 Initial Guess (ms)'
                ,hidden=hiddens[3])
    x0_range_3 = mr.Range(value=parsec.wdict['x0_range_3'],  #ms
                            min=np.around(parsec.state_dict['time_axis'][parsec.state_dict['timestart']-int(2**logwindow_slider.value)]*1e-3,2),#x0_guess_0.value*(1 - scatter_sliderrange.value), 
                            max=np.around(parsec.state_dict['time_axis'][parsec.state_dict['timestop']+int(2**logwindow_slider.value)]*1e-3,2),#x0_guess_0.value*(1 + scatter_sliderrange.value), 
                            label=r'(Comp 3) x0 Search Range (ms)', 
                            step=32.7e-3
                    ,hidden=hiddens[3])
    if not hiddens[3]:
        x0_guess_comps.append(x0_guess_3)
        x0_range_sliders.append(x0_range_3)
        
    amp_guess_3 = mr.Numeric(value=parsec.wdict['amp_guess_3'], 
                         step=1e-3,
                         min=0,max=500,
                         label=r'(Comp 3) Amplitude Initial Guess'
                        ,hidden=hiddens[3])
    amp_range_3 = mr.Range(value=parsec.wdict['amp_range_3'],  #ms
                            min=0,#amp_guess_0.value*(1 - scatter_sliderrange.value), 
                            max=500,#amp_guess_0.value*(1 + scatter_sliderrange.value), 
                            label=r'(Comp 3) Amplitude Search Range', 
                            step=1e-3
                    ,hidden=hiddens[3])
    if not hiddens[3]:
        amp_guess_comps.append(amp_guess_3)
        amp_range_sliders.append(amp_range_3)

    sigma_guess_3 = mr.Numeric(value=parsec.wdict['sigma_guess_3'], 
                         step=1e-3,
                         min=0,#x0_guess_0.value*(1 - scatter_sliderrange.value), 
                            max=np.around((parsec.state_dict['time_axis'][parsec.state_dict['timestop']+int(2**logwindow_slider.value)] -
                                 parsec.state_dict['time_axis'][parsec.state_dict['timestart']-int(2**logwindow_slider.value)])*1e-3,2),#x0_guess_0.value*(1 + scatter_sliderrange.value), 
                            label=r'(Comp 3) sigma Initial Guess (ms)'
                        ,hidden=hiddens[3])
    sigma_range_3 = mr.Range(value=parsec.wdict['sigma_range_3'],  #ms
                            min=0,#x0_guess_0.value*(1 - scatter_sliderrange.value), 
                            max=np.around((parsec.state_dict['time_axis'][parsec.state_dict['timestop']+int(2**logwindow_slider.value)] -
                                 parsec.state_dict['time_axis'][parsec.state_dict['timestart']-int(2**logwindow_slider.value)])*1e-3,2),#x0_guess_0.value*(1 + scatter_sliderrange.value), 
                            label=r'(Comp 3) sigma Search Range (ms)', 
                            step=1e-3
                    ,hidden=hiddens[3])
    if not hiddens[3]:
        sigma_guess_comps.append(sigma_guess_3)
        sigma_range_sliders.append(sigma_range_3)

    tau_guess_3 = mr.Numeric(value=parsec.wdict['tau_guess_3'], 
                         step=1e-3,
                         min=0,#x0_guess_0.value*(1 - scatter_sliderrange.value), 
                            max=np.around((parsec.state_dict['time_axis'][parsec.state_dict['timestop']+int(2**logwindow_slider.value)] -
                                 parsec.state_dict['time_axis'][parsec.state_dict['timestart']-int(2**logwindow_slider.value)])*1e-3,2),#x0_guess_0.value*(1 + scatter_sliderrange.value), 
                            label=r'(Comp 3) tau Search Range (ms)'
                        ,hidden=hiddens[3])
    tau_range_3 = mr.Range(value=parsec.wdict['tau_range_3'],  #ms
                            min=0,#x0_guess_0.value*(1 - scatter_sliderrange.value), 
                            max=np.around((parsec.state_dict['time_axis'][parsec.state_dict['timestop']+int(2**logwindow_slider.value)] -
                                 parsec.state_dict['time_axis'][parsec.state_dict['timestart']-int(2**logwindow_slider.value)])*1e-3,2),#x0_guess_0.value*(1 + scatter_sliderrange.value), 
                            label=r'(Comp 3) tau Search Range (ms)', 
                            step=1e-3
                    ,hidden=hiddens[3])
    if not hiddens[3]:
        tau_guess_comps.append(tau_guess_3)
        tau_range_sliders.append(tau_range_3)
        
    #comp 4
    hiddens.append(hidden | ('Component 4' not in scattermenu.value))
    #if not hiddens[0]:
    #    note_0 = mr.Note('Component 0')         
    x0_guess_4 = mr.Numeric(value=parsec.wdict['x0_guess_4'], 
                 step=32.7e-3,
                 min=np.around(parsec.state_dict['time_axis'][parsec.state_dict['timestart']-int(2**logwindow_slider.value)]*1e-3,2),#x0_guess_0.value*(1 - scatter_sliderrange.value), 
                            max=np.around(parsec.state_dict['time_axis'][parsec.state_dict['timestop']+int(2**logwindow_slider.value)]*1e-3,2),#x0_guess_0.value*(1 + scatter_sliderrange.value), 
                            label=r'(Comp 4) x0 Initial Guess (ms)'
                ,hidden=hiddens[4])
    x0_range_4 = mr.Range(value=parsec.wdict['x0_range_4'],  #ms
                            min=np.around(parsec.state_dict['time_axis'][parsec.state_dict['timestart']-int(2**logwindow_slider.value)]*1e-3,2),#x0_guess_0.value*(1 - scatter_sliderrange.value), 
                            max=np.around(parsec.state_dict['time_axis'][parsec.state_dict['timestop']+int(2**logwindow_slider.value)]*1e-3,2),#x0_guess_0.value*(1 + scatter_sliderrange.value), 
                            label=r'(Comp 4) x0 Search Range (ms)', 
                            step=32.7e-3
                    ,hidden=hiddens[4])
    if not hiddens[4]:
        x0_guess_comps.append(x0_guess_4)
        x0_range_sliders.append(x0_range_4)
        
    amp_guess_4 = mr.Numeric(value=parsec.wdict['amp_guess_4'], 
                         step=1e-3,
                         min=0,max=500,
                         label=r'(Comp 4) Amplitude Initial Guess'
                        ,hidden=hiddens[4])
    amp_range_4 = mr.Range(value=parsec.wdict['amp_range_4'],  #ms
                            min=0,#amp_guess_0.value*(1 - scatter_sliderrange.value), 
                            max=500,#amp_guess_0.value*(1 + scatter_sliderrange.value), 
                            label=r'(Comp 4) Amplitude Search Range', 
                            step=1e-3
                    ,hidden=hiddens[4])
    if not hiddens[4]:
        amp_guess_comps.append(amp_guess_4)
        amp_range_sliders.append(amp_range_4)

    sigma_guess_4 = mr.Numeric(value=parsec.wdict['sigma_guess_4'], 
                         step=1e-3,
                         min=0,#x0_guess_0.value*(1 - scatter_sliderrange.value), 
                            max=np.around((parsec.state_dict['time_axis'][parsec.state_dict['timestop']+int(2**logwindow_slider.value)] -
                                 parsec.state_dict['time_axis'][parsec.state_dict['timestart']-int(2**logwindow_slider.value)])*1e-3,2),#x0_guess_0.value*(1 + scatter_sliderrange.value), 
                            label=r'(Comp 4) sigma Initial Guess (ms)'
                        ,hidden=hiddens[4])
    sigma_range_4 = mr.Range(value=parsec.wdict['sigma_range_4'],  #ms
                            min=0,#x0_guess_0.value*(1 - scatter_sliderrange.value), 
                            max=np.around((parsec.state_dict['time_axis'][parsec.state_dict['timestop']+int(2**logwindow_slider.value)] -
                                 parsec.state_dict['time_axis'][parsec.state_dict['timestart']-int(2**logwindow_slider.value)])*1e-3,2),#x0_guess_0.value*(1 + scatter_sliderrange.value), 
                            label=r'(Comp 4) sigma Search Range (ms)', 
                            step=1e-3
                    ,hidden=hiddens[4])
    if not hiddens[4]:
        sigma_guess_comps.append(sigma_guess_4)
        sigma_range_sliders.append(sigma_range_4)

    tau_guess_4 = mr.Numeric(value=parsec.wdict['tau_guess_4'], 
                         step=1e-3,
                         min=0,#x0_guess_0.value*(1 - scatter_sliderrange.value), 
                            max=np.around((parsec.state_dict['time_axis'][parsec.state_dict['timestop']+int(2**logwindow_slider.value)] -
                                 parsec.state_dict['time_axis'][parsec.state_dict['timestart']-int(2**logwindow_slider.value)])*1e-3,2),#x0_guess_0.value*(1 + scatter_sliderrange.value), 
                            label=r'(Comp 4) tau Search Range (ms)'
                        ,hidden=hiddens[4])
    tau_range_4 = mr.Range(value=parsec.wdict['tau_range_4'],  #ms
                            min=0,#x0_guess_0.value*(1 - scatter_sliderrange.value), 
                            max=np.around((parsec.state_dict['time_axis'][parsec.state_dict['timestop']+int(2**logwindow_slider.value)] -
                                 parsec.state_dict['time_axis'][parsec.state_dict['timestart']-int(2**logwindow_slider.value)])*1e-3,2),#x0_guess_0.value*(1 + scatter_sliderrange.value), 
                            label=r'(Comp 4) tau Search Range (ms)', 
                            step=1e-3
                    ,hidden=hiddens[4])
    if not hiddens[4]:
        tau_guess_comps.append(tau_guess_4)
        tau_range_sliders.append(tau_range_4)
       

    calc_scat_button = mr.Button(label='Calculate Scattering Parameters',
                             style='primary',hidden=hidden)
    save_scat_button = mr.Button(label='Save To File',style='primary',hidden=hidden)
    
    try:
        scatterresult = parsec.scatter_screen(scattermenu,scatfitmenu,x0_guess_comps,sigma_guess_comps,tau_guess_comps,amp_guess_comps,
                                                                  x0_range_sliders,sigma_range_sliders,tau_range_sliders,amp_range_sliders,
                                                                  calc_scat_button,save_scat_button,scatterbackground,refresh_button,
                                                                  scatterresume,scatterweights,scatter_nlive,scatter_sliderrange,
                                                                  scattersamps,scatter_nwalkers,scatter_nsteps,scatter_nburn,scatter_nthin,logwindow_slider)
    except KeyError as ex:
        print("Preceding Stages Required")

    
    
#(5) SCINTILLATION
hidden = toggle_menu.value != '(5) Scintillation Analysis'
if not hidden:
    mr.Markdown("### (5) Scintillation Analysis")
    try:
        parsec.scint_screen(scintfitmenu,calc_bw_button,gamma_guess,m_guess,c_guess,scintmenu,scint_fit_range,save_scint_button)
    except KeyError as ex:
        print("Preceding Stages Required")
        
#(6) RM ANALYSIS

#widgets for filter weights dashboard
hidden = toggle_menu.value != '(6) RM Synthesis'
if not hidden:
    mr.Markdown("### (6) RM Synthesis")
    if printRM2Dwarning:
        print("Warning: Note that 2D and/or Zoom RM synthesis can only be run after Initial RM Synthesis with either RM-Tools or 1D RM Synthesis which are used for the initial guess. Confirm you have run these before proceeding with 2D or Zoom RM Synthesis.")
    try:
        parsec.RM_screen(useRMTools,maxRM_num_tools,dRM_tools,useRMsynth,nRM_num,minRM_num,
                     maxRM_num,getRMbutton,useRM2D,nRM_num_zoom,RM_window_zoom,dRM_tools_zoom,getRMbutton_zoom,
                    RM_gal_display,RM_galerr_display,RM_ion_display,RM_ionerr_display,getRMgal_button,getRMion_button,
                    rmcomp_menu,RMsynthbackground,refresh_button,maxthreads,maxbatches,maxtrials_per_thread)
    except KeyError as ex:
        print("Preceding Stages Required")
        
#(7) RM DM Bfield budget
hidden = toggle_menu.value != '(7) RM, DM, Bfield Budget'
if not hidden:
    mr.Markdown("#### Galaxy Query")
    try:
        parsec.galquery_Budget_screen(catalog_selection,galtype_selection,queryradius,runquerybutton,
                                       limitzrange,zrange,trialz,cosmo_selection)
    except KeyError as ex:
        print("Preceding Stages Required")
    
    #choose mass for galaxies you want to include
    galaxy_selection =  mr.MultiSelect(label="Select Galaxies to Include in DM Budget", 
                          value=parsec.wdict['galaxy_selection'], 
                          choices=parsec.wdict['galaxy_selection_choices'],
                           hidden=hidden)
    
    mass_type = mr.Select(label='Mass Factor',
                         value=parsec.wdict['mass_type'],
                         choices=parsec.wdict['mass_type_choices'],
                         hidden=hidden)
    
    #choose virial mass for each intervening galaxy/cluster
    galaxy_masses = mr.Text(value=parsec.wdict['galaxy_masses'],
                            label='Masses/Mass Ranges of Additional Galaxies (Msun, separated by commas, e.g. 1e6,1e7--1e10,1e3)',
                           hidden=hidden)
    
    #choose line-of-sight B field for each intervening galaxy/cluster
    galaxy_bfields = mr.Text(value=parsec.wdict['galaxy_bfields'],
                            label='Magnetic Fields/Field Ranges of Additional Galaxies (uG or times Milky Way Field Strength, separated by commas, e.g. 1e6uG,10x)',
                           hidden=hidden)
    try:
        qdat = parsec.galplot_Budget_screen(catalog_selection,galtype_selection,queryradius,runquerybutton,
                                 limitzrange,zrange,trialz,cosmo_selection,galaxy_masses,galaxy_selection,
                                        mass_type,galaxy_bfields)
    except KeyError as ex:
        qdat = None
        print("Preceding Stages Required")
#(7) POLARIZATION ANALYSIS
hidden = toggle_menu.value != '(8) Polarization Analysis'
if not hidden:
    mr.Markdown("### (8) Polarization Analysis")
    try:
        fig,fig_time,fig_freq = parsec.polanalysis_screen(showghostPA,intLbuffer_slider,intRbuffer_slider,polcomp_menu,saveplotbutton,showpolfracs)
    except KeyError as ex:
        fig = fig_time = fig_freq = None
        print("Preceding Stages Required")
    mr.Markdown("#### Pol and S/N Table")
    nbox=mr.Table(data=parsec.poldf, width="200px")

    
#(8) ARCHIVE
#widgets for pol analysis dashboard
hidden = toggle_menu.value != '(9) Archive Data'
if not hidden:
    mr.Markdown("### (9) Archive Data")
    try:
        parsec.archive_screen(savebutton,archivebutton,archivepolcalbutton,
                              spreadsheetbutton,txtfilebutton,
                              notesinput,overwritefils)
    except KeyError as ex:
        print("Preceding Stages Required")
    mr.Markdown("#### RM Table (See Van Eck et al. 2023)")
    nbox = mr.Table(data=parsec.RMtable_archive_df.to_pandas(), width="200px")#, text_align="center")

# (10) HELP
hidden = toggle_menu.value != '(10) Help'
if not hidden:
    #nbox = mr.PDF(file_path=parsec.dirs['cwd'] + "PARSECtutorial.pdf",width="100%",height="500")
    #with open(parsec.dirs['cwd'] + "/README.md","r") as f:
    #    dat = f.read()
    #f.close()
    mr.Markdown(text="Scroll down for a tutorial on `PARSEC` and FAQs. For more info, visit https://github.com/dsa110/dsa110-pol.") 
    
nbox
# Out:
# ### (8) Polarization Analysis
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 569
#     567 mr.Markdown("### (8) Polarization Analysis")
#     568 #try:
# --> 569 fig,fig_time,fig_freq = parsec.polanalysis_screen(showghostPA,intLbuffer_slider,intRbuffer_slider,polcomp_menu,saveplotbutton,showpolfracs)
#     570 #except KeyError as ex:
#     571 #    fig = fig_time = fig_freq = None
#     572 #    print("Preceding Stages Required")
#     573 mr.Markdown("#### Pol and S/N Table")
#
# File ~/msherman_nsfrb/miniconda/envs/casa38dsapol/lib/python3.8/site-packages/dsapol/parsec.py:4621, in polanalysis_screen(showghostPA, intLbuffer_slider, intRbuffer_slider, polcomp_menu, saveplotbutton, showpolfracs)
#    4619     V_tuse = state_dict['V_t']
#    4620 else:
# -> 4621     raise KeyError
#    4624 #get intL and intR from slider
#    4625 n_off = int(NOFFDEF/state_dict['n_t'])
#
# KeyError:

# %%
nbox = None
#(0) LOAD DATA,(ADMIN) MAKE FILS
hidden = toggle_menu.value not in ['(ADMIN) Make Filterbanks','(0) Load Data'] #!= '(0) Load Data'
if not hidden:
    #display filterbank files if they exist
    if 'fils' in parsec.state_dict.keys():
        if len(parsec.state_dict['fils']) == 0:
            mr.Markdown(text=r'##### **Filterbanks:** None Found')
        else:
            mr.Markdown(text=r'##### **Filterbanks:** ')
            for f in parsec.state_dict['fils']:
                mr.Markdown(r'###### -' + str(f))

    #display beamformer weights date if exists
    if 'bfweights' in parsec.state_dict.keys():
        if parsec.state_dict['bfweights'] is None:
            bfweights_text = r'##### **Beamformer Weights:** None Found'
        else:
            bfweights_text = r'##### **Beamformer Weights:** ' + parsec.state_dict['bfweights']
        bfweights_display = mr.Markdown(text=bfweights_text)

    
#(1) DEDISPERSION

hidden=toggle_menu.value != '(1) Dedispersion Tuning'
if not hidden:
    try:
        
        mr.Markdown("##### DM Parameters")


        #if not (parsec.state_dict["current_state"] >= parsec.state_map['dedisp']): raise parsec.StopExecution
        DM_input_display = mr.NumberBox(data=parsec.wdict['DM_input_display'],#parsec.FRB_DM[parsec.FRB_IDS.index(ids)], 
                                        title=r'Input DM (pc/cm$^{{3}}$)'
                                       )
        DM_new_display = mr.NumberBox(data=DM_input_display.data + parsec.wdict['ddm_num'], 
                                      title=r'New DM (pc/cm$^{{3}}$)'
                                     )

        nbox=mr.NumberBox([DM_input_display,DM_new_display])

        
    except KeyError as ex:
        print("Preceding Stages Required")


    
#(2) CALIBRATION

hidden = ('Calibration' not in toggle_menu.value ) or (not ADMINMODE)
if not hidden:
    
    mr.Markdown(" Polarization Calibration Solution:" + str(" Pol Calibrated Filterbanks have been loaded, so the Calibrate function is not available." if parsec.state_dict['polcaldataloaded'] else ""))
    
    try:
        nbox = parsec.polcal_screen_ADMIN(polcaldate_menu,polcaldate_create_menu,polcaldate_bf_menu,polcaldate_findbeams_menu,obsid3C48_menu,obsid3C286_menu,
                                                         polcalbutton,polcopybutton,bfcal_button,findbeams_button,filcalbutton,ParA_display,
                                                         edgefreq_slider,breakfreq_slider,sf_window_weight_cals,sf_order_cals,peakheight_slider,peakwidth_slider,polyfitorder_slider,
                                                         ratio_edgefreq_slider,ratio_breakfreq_slider,ratio_sf_window_weight_cals,ratio_sf_order_cals,ratio_peakheight_slider,ratio_peakwidth_slider,ratio_polyfitorder_slider,
                                                         phase_sf_window_weight_cals,phase_sf_order_cals,phase_peakheight_slider,phase_peakwidth_slider,phase_polyfitorder_slider,savecalsolnbutton,
                                                         sfflag,polyfitflag,ratio_sfflag,ratio_polyfitflag,phase_sfflag,phase_polyfitflag,beam_dict_3C48,beam_dict_3C286,saveplotbutton)
    except KeyError as ex:
        print("Preceding Stages Required")
        

hidden = (toggle_menu.value != '(2) Calibration -- Calibrate') or ADMINMODE
if not hidden:
    
    
    mr.Markdown("Calibrated Dynamic Spectra")
    try:
        parsec.polcal_dynspecplot_screen(logwindow_slider)
    except KeyError as ex:
        print("Preceding Stages Required")
        
#(3) FILTERING
hidden = toggle_menu.value != '(3) Filter Weights'
if not hidden:
    nbox = mr.Table(data=parsec.df, width="200px")#, text_align="center")
    
#(4) SCATTERING
#widgets for scattering dashboard
hidden = toggle_menu.value != '(4) Scattering Analysis'
if not hidden:
    mr.Markdown("Scattering Analysis Corner Plot:")
    if scatterresult is not None and (scatfitmenu.value == 'Nested Sampling'):
        figscatter = plt.figure(figsize=(18,10))
        nbox = scatterresult.plot_corner(fig=figscatter)
        if scatterbackground.value:
            os.system("cp " + parsec.dirs['logs'] + "scat_files/" + parsec.state_dict['scatter_bilby_dname'] + "* " + parsec.state_dict['datadir'])
    elif scatterresult is not None and (scatfitmenu.value == 'EMCEE Markov-Chain Monte Carlo'):
        
        figscatter = plt.figure(figsize=(18,10))
        labels = np.concatenate([['x0'+str(i),'amp'+str(i),r'$\sigma$'+str(i),r'$\tau$'+str(i)] for i in range(scatterresult.shape[1]//4)])
        corner.corner(scatterresult,labels=labels,fig=figscatter,show_titles=True,quantiles=[0.16,0.50,0.84],label_kwargs={'fontsize':parsec.fsize})
        if scatterbackground.value:
            os.system("cp " + parsec.dirs['logs'] + "scat_files/" + parsec.state_dict['scatter_MCMC_dname'] + "* " + parsec.state_dict['datadir'])
    
#(5) SCINTILLATION
hidden = toggle_menu.value != '(5) Scintillation Analysis'
if not hidden:
    mr.Markdown("Scintillation Analysis Results:")
    nbox = mr.Table(data=parsec.df_scint, width="400px")

#(6) RM ANALYSIS

#widgets for filter weights dashboard
hidden = toggle_menu.value != '(6) RM Synthesis'
if not hidden:
    
    #update rm cal menu
    parsec.update_wdict([None],['rmcal_menu'],param='value',skipdict=True)
    rmcal_menu = mr.Select(label="Calibration RM:", 
                                value=parsec.wdict['rmcal_menu'],
                                choices=parsec.wdict['rmcal_menu_choices'],
                                hidden=hidden)#frbfiles[0], choices=frbfiles,hidden=hidden)

    rmcal_input = mr.Numeric(value=parsec.wdict['rmcal_input'], 
                         step=0.01,
                         min=-1e6,max=1e6,
                         label='Input RM (rad/m$^{{2}}$)',
                         hidden=(hidden | ('Input RM' not in rmcal_menu.value)))


    RMcalibratebutton = mr.Button(label='Apply RM Calibration',
                                 style='primary',hidden=hidden)
    
    
    try:
        parsec.RM_screen_plot(rmcal_menu,RMcalibratebutton,RMdisplay,RMerrdisplay,rmcal_input)
    except KeyError as ex:
        print("Preceding Stages Required")

#(7) RM, DM, Bfield Budget

#widgets for filter weights dashboard
hidden = toggle_menu.value != '(7) RM, DM, Bfield Budget'
if not hidden:
    
    mr.Markdown("#### SIMBAD Intervening Object Query Results")
    if qdat is not None:
        nbox=mr.Table(data=qdat.to_pandas(), width="200px",lengthMenu=[4])
                      
    """[['MAIN_ID','RA','DEC','GALDIM_MAJAXIS',
                     'GALDIM_MINAXIS','GALDIM_ANGLE','OTYPE',
                     'RVZ_RADVEL','RVZ_ERROR','COMOVING_DIST_EST',
                     'COMOVING_DIST_EST_POSERR','COMOVING_DIST_EST_NEGERR',
                     'OFFSET','IMPACT',
                     'IMPACT_POSERR','IMPACT_NEGERR',
                     'M_INPUT','M_INPUT_ERROR',
                     'R_EST','R_EST_ERROR',
                     'DM_EST','DM_EST_ERROR',
                     'B_LOS_EST','B_LOS_EST_ERROR',
                     'B0_LOS_EST','B0_LOS_EST_ERROR',
                     'RM_EST','RM_EST_ERROR']]"""
    
    

#(8) POLARIZATION ANALYSIS
hidden = toggle_menu.value != '(8) Polarization Analysis'
if not hidden:
    mr.Markdown("#### Summary Plot")
    nbox = fig
    
#(9) ARCHIVE
#widgets for pol analysis dashboard
hidden = toggle_menu.value != '(9) Archive Data'
if not hidden:
    # display the output of the logfile
    mr.Markdown(" Log:")
    #if showlogcal.value:# or refreshlogbutton.clicked:
    flog = open(rmtablefuncs.logfile,"r")
    logtext = flog.read()
    flog.close()
    mr.Markdown(text=(logtext.replace('\n','\n\n')))

# (10) HELP
hidden = toggle_menu.value != '(10) Help'
if not hidden:
    nbox = mr.PDF(file_path=parsec.dirs['cwd'] + "PARSECtutorial.pdf",width="100%",height="500")
    #with open(parsec.dirs['cwd'] + "/README.md","r") as f:
    #    dat = f.read()
    #f.close()
    #mr.Markdown(text=dat)
    
    
nbox

# %%
nbox = None
#(0) LOAD DATA
hidden = toggle_menu.value not in ['(ADMIN) Make Filterbanks','(0) Load Data'] #!= '(0) Load Data'
if not hidden:
    mr.Markdown("##### FRB Parameters")
    nbox=mr.NumberBox([RA_display,DEC_display,z_display,ibeam_display,ibox_display])
    
#(1) DEDISPERSION

hidden=toggle_menu.value != '(1) Dedispersion Tuning'
if not hidden:
        
    mr.Markdown("De-dispersed Dynamic Spectra")
    try:
        parsec.dedisp_dynspecplot_screen(logwindow_slider)
    except KeyError as ex:
        print("Preceding Stages Required")
    
    
#(2) CALIBRATION


hidden = ('Calibration' not in toggle_menu.value ) or (not ADMINMODE)
if not hidden:
    
        
    mr.Markdown("Calibrated Dynamic Spectra")
    try:
        parsec.polcal_dynspecplot_screen(logwindow_slider)
    except KeyError as ex:
        print("Preceding Stages Required")
hidden = (toggle_menu.value != '(2) Calibration -- Calibrate') or ADMINMODE
if not hidden:     
    mr.Markdown(" Parallactic Angle Estimate:")
    #if not (parsec.state_dict["current_state"] >= parsec.state_map['polcal']): raise parsec.StopExecution
    nbox = ParA_display
    
    
#(3) FILTERING
hidden = toggle_menu.value != '(3) Filter Weights'
if not hidden:
    nbox=mr.NumberBox([Iflux_display,Qflux_display,Uflux_display,Vflux_display])
    
#(4) SCATTERING
#widgets for scattering dashboard
hidden = toggle_menu.value != '(4) Scattering Analysis'
if not hidden:
    mr.Markdown("Scattering Analysis Results:")
    nbox=mr.Table(data=parsec.df_scat, width="400px")


    
#(5) SCINTILLATION
hidden = toggle_menu.value != '(5) Scintillation Analysis'
if not hidden:
    
    mr.Markdown("### (5) Spectral Index Analysis")
    try:
        parsec.specidx_screen(specidxfitmenu,calc_specidx_button,specidx_guess,F0_guess,specidxmenu,save_specidx_button)
    except KeyError as ex:
        print("Preceding Stages Required")
        
    
#(6) RM ANALYSIS

#widgets for filter weights dashboard
hidden = toggle_menu.value != '(6) RM Synthesis'
if not hidden:
    mr.Markdown("#### RM Applied")
    nbox=mr.NumberBox([RMdisplay,RMerrdisplay])
    
#(7) RM, DM, Bfield Budget

#widgets for filter weights dashboard
hidden = toggle_menu.value != '(7) RM, DM, Bfield Budget'
if not hidden:
    mr.Markdown("#### DM Budget")
    try:
        parsec.DM_Budget_screen(trialz)
    except KeyError as ex:
        print("Preceding Stages Required")
    nbox = mr.Table(data=parsec.df_DM_budget, width="200px")
        
    

#(8) POLARIZATION ANALYSIS
hidden = toggle_menu.value != '(8) Polarization Analysis'
if not hidden:
    mr.Markdown("#### Time Domain")
    nbox=fig_time
    
#(9) ARCHIVE
#widgets for pol analysis dashboard
hidden = toggle_menu.value != '(9) Archive Data'
#if not hidden:
#    pass


# (10) HELP
hidden = toggle_menu.value != '(10) Help'
if not hidden:
    mr.Markdown(text="## FAQs")
    mr.Markdown(text="### Q: What is the difference between USER and ADMIN mode?")
    mr.Markdown(text="#### A: USER mode provides an interface for the most common polarization and burst property analysis, including RM synthesis, calibration, and morphological fitting. It does not allow the user to alter or overwrite filterbank data on disk. ADMIN mode allows the user to update filterbank files and archive data. It also provides an interface for creating new calibration solutions rather than just giving access to existing ones. The ADMIN mode should only be used after obtaining the password from and discussing with the PARSEC system administrator (Myles Sherman; msherman@caltech.edu) to avoid accidental data loss.")
    
    

    
nbox

# %%
nbox = None
#(0) LOAD DATA
hidden = toggle_menu.value not in ['(ADMIN) Make Filterbanks','(0) Load Data'] #!= '(0) Load Data'
if not hidden:
    nbox=mr.NumberBox([mjd_display,DM_init_display])

#(6) RM ANALYSIS
#widgets for filter weights dashboard
hidden = toggle_menu.value != '(6) RM Synthesis'
if not hidden:
    
    mr.Markdown("#### RM Table")
    nbox =mr.Table(data=parsec.RMdf, width="200px")#, text_align="center")
nbox

# %%
nbox = None
#(ADMIN) Make Filterbanks
hidden = toggle_menu.value != '(ADMIN) Make Filterbanks'
if not hidden:
    
    mr.Markdown("##### Log:")
    #if showlog.value:# or refreshlogbutton.clicked:
    flog = open(polbeamform.logfile,"r")
    logtext = flog.read()
    flog.close()
    mr.Markdown(text=(logtext.replace('\n','\n\n')))


#(0) LOAD DATA
hidden = toggle_menu.value != '(0) Load Data'
if not hidden:
    mr.Markdown("Dynamic Spectra")
    try:
        parsec.load_dynspecplot_screen(logwindow_slider,n_t_slider,logn_f_slider)
    except KeyError as ex:
        print("Preceding Stages Required")
#(1) DEDISPERSION

hidden=toggle_menu.value != '(1) Dedispersion Tuning'
if not hidden:
    
    # display the output of the logfile
    mr.Markdown(" Log:")
    #if showlogcal.value:# or refreshlogbutton.clicked:
    flog = open(dedisp.logfile,"r")
    logtext = flog.read()
    flog.close()
    mr.Markdown(text=(logtext.replace('\n','\n\n')))



    
#(2) CALIBRATION


hidden = ('Calibration' not in toggle_menu.value ) or (not ADMINMODE)
if not hidden:
    mr.Markdown(" Parallactic Angle Estimate:")
    #if not (parsec.state_dict["current_state"] >= parsec.state_map['polcal']): raise parsec.StopExecution
    nbox = ParA_display
    
hidden = (toggle_menu.value != '(2) Calibration -- Calibrate') or ADMINMODE
if not hidden:
    
    
    # display the output of the logfile
    mr.Markdown(" Log:")
    #if showlogcal.value:# or refreshlogbutton.clicked:
    flog = open(polcal.logfile,"r")
    logtext = flog.read()
    flog.close()
    mr.Markdown(text=(logtext.replace('\n','\n\n')))
    
#(3) FILTERING
hidden = toggle_menu.value != '(3) Filter Weights'
if not hidden:
    # display the output of the logfile
    mr.Markdown(" Log:")
    #if showlogcal.value:# or refreshlogbutton.clicked:
    flog = open(filt.logfile,"r")
    logtext = flog.read()
    flog.close()
    mr.Markdown(text=(logtext.replace('\n','\n\n')))
    
#(4) SCATTERING
#widgets for scattering dashboard
hidden = toggle_menu.value != '(4) Scattering Analysis'
if not hidden:
    # display the output of the logfile
    mr.Markdown("##### Log:")
    #if showlogcal.value:# or refreshlogbutton.clicked:
    flog = open(scatscint.logfile,"r")
    logtext = flog.read()
    flog.close()
    mr.Markdown(text=(logtext.replace('\n','\n\n')))
    
#(5) SCINTILLATION
hidden = toggle_menu.value != '(5) Scintillation Analysis'
if not hidden:
    mr.Markdown("Spectral Index Analysis Results:")
    nbox = mr.Table(data=parsec.df_specidx, width="400px")




#(6) RM ANALYSIS

#widgets for filter weights dashboard
hidden = toggle_menu.value != '(6) RM Synthesis'
if not hidden:
    
    mr.Markdown("RM-Calibrated Dynamic Spectra")
    try:
        parsec.RM_dynspecplot_screen(logwindow_slider)
    except KeyError as ex:
        print("Preceding Stages Required")

#(7) RM, DM, Bfield Budget

#widgets for filter weights dashboard
hidden = toggle_menu.value != '(7) RM, DM, Bfield Budget'
if not hidden:
    mr.Markdown("#### RM Budget")
    try:
        parsec.RM_Budget_screen(trialz)
    except KeyError as ex:
        print("Preceding Stages Required")
    nbox = mr.Table(data=parsec.df_RM_budget, width="200px")

#(8) POLARIZATION ANALYSIS
hidden = toggle_menu.value != '(8) Polarization Analysis'
if not hidden:
    mr.Markdown("#### Spectrum")
    nbox = fig_freq
    
#(9) ARCHIVE
#widgets for pol analysis dashboard
hidden = toggle_menu.value != '(9) Archive Data'
#if not hidden:
#    pass
    
nbox

# %%
nbox = None
#(0) LOAD DATA
hidden = toggle_menu.value != '(0) Load Data'
if not hidden:
    
    mr.Markdown("##### Log:")
    #if showlog.value:# or refreshlogbutton.clicked:
    flog = open(polbeamform.logfile,"r")
    logtext = flog.read()
    flog.close()
    mr.Markdown(text=(logtext.replace('\n','\n\n')))
    
#(1) DEDISPERSION

hidden=toggle_menu.value != '(1) Dedispersion Tuning'
#if not hidden:
#    pass

    
#(2) CALIBRATION



hidden = ('Calibration' not in toggle_menu.value ) or (not ADMINMODE)
if not hidden:
    mr.Markdown(" Table of Pol Cal Voltages on T3:")
    nbox = mr.Table(data=parsec.df_polcal, width="200px")
        
    
        
#(3) FILTERING
hidden = toggle_menu.value != '(3) Filter Weights'
#if not hidden:
#    pass
    
#(4) SCATTERING
#widgets for scattering dashboard
hidden = toggle_menu.value != '(4) Scattering Analysis'
#if not hidden:
#    pass
    
#(5) SCINTILLATION
hidden = toggle_menu.value != '(5) Scintillation Analysis'
if not hidden:
    # display the output of the logfile
    mr.Markdown(" Log:")
    #if showlogcal.value:# or refreshlogbutton.clicked:
    flog = open(scatscint.logfile,"r")
    logtext = flog.read()
    flog.close()
    mr.Markdown(text=(logtext.replace('\n','\n\n')))



#(6) RM ANALYSIS

#widgets for filter weights dashboard
hidden = toggle_menu.value != '(6) RM Synthesis'
if not hidden:
    
    nbox=mr.NumberBox([RM_gal_display,RM_galerr_display,RM_ion_display,RM_ionerr_display])
    
    
#(7) RM, DM, Bfield Budget

#widgets for filter weights dashboard
hidden = toggle_menu.value != '(7) RM, DM, Bfield Budget'
if not hidden: 
    mr.Markdown("#### Host B Field Estimate")
    
    
    getBfieldbutton = mr.Button(label='Generate B field Budget',
                                style='primary',
                               hidden=hidden)
    Bfield_range = mr.Numeric(value=parsec.wdict['Bfield_range'], #DM offset
                         step=1e-1,
                         min=0,max=100000,
                         label='Range of B||,host around Initial Estimate (uG)'
                        ,hidden=hidden)
    Bfield_res = mr.Numeric(value=parsec.wdict['Bfield_res'],
                           step=1e-3,
                         min=0,max=1000,
                         label='Resolution of B||,host axis (uG)'
                        ,hidden=hidden)
    
    try:
        parsec.Bfield_Budget_screen(getBfieldbutton,Bfield_range,Bfield_res) 
    except KeyError as ex:
        print("Preceding Stages Required")
    Bfield_display = mr.NumberBox(data=parsec.wdict['Bfield_display'], title=r'$B_{\rm ||,host} (\mu G)$')
    Bfield_pos_err_display = mr.NumberBox(data=parsec.wdict['Bfield_pos_err_display'], title=r'$\sigma_{B_{\rm ||,host},+} (\mu G)$')
    Bfield_neg_err_display = mr.NumberBox(data=parsec.wdict['Bfield_neg_err_display'], title=r'$\sigma_{B_{\rm ||,host},-} (\mu G)$')
    nbox = mr.NumberBox([Bfield_display,Bfield_pos_err_display,Bfield_neg_err_display])
    
#(8) POLARIZATION ANALYSIS
hidden = toggle_menu.value != '(8) Polarization Analysis'
if not hidden:
    # display the output of the logfile
    mr.Markdown(" Log:")
    #if showlogcal.value:# or refreshlogbutton.clicked:
    flog = open(dsapol.logfile,"r")
    logtext = flog.read()
    flog.close()
    mr.Markdown(text=(logtext.replace('\n','\n\n')))
    
#(9) ARCHIVE
#widgets for pol analysis dashboard
hidden = toggle_menu.value != '(9) Archive Data'
#if not hidden:
#    pass
    
nbox

# %%
nbox = None
#(0) LOAD DATA
hidden = toggle_menu.value != '(0) Load Data'
#if not hidden:
#    pass
    
#(1) DEDISPERSION

hidden=toggle_menu.value != '(1) Dedispersion Tuning'
#if not hidden:
#    pass

    
#(2) CALIBRATION



hidden = ('Calibration' not in toggle_menu.value ) or (not ADMINMODE)
if not hidden:
    mr.Markdown(" Selected 3C48 Pol Cal Files:")
    #display voltages and beamformer weight files for current selection
    if polcaldate_bf_menu.value != "":
        #display filterbank files if they exist
        if 'polcal_avail_3C48' in parsec.polcal_dict.keys():
            if len(parsec.polcal_dict['polcal_avail_3C48']) == 0:
                mr.Markdown(text=r'###### **3C48 Voltages:** None Found')
            else:
                mr.Markdown(text=r'###### **3C48 Voltages:** ')
                for f in parsec.state_dict['polcal_avail_3C48']:
                    mr.Markdown(r'- ######' + f)
        if 'polcal_avail_bf_3C48' in parsec.polcal_dict.keys():
            if len(parsec.polcal_dict['polcal_avail_bf_3C48']) == 0:
                mr.Markdown(text=r'##### **3C48 Beamformer Weights:** None Found')
            else:
                mr.Markdown(text=r'##### **3C48 Beamformer Weights:** ')
                for f in parsec.state_dict['polcal_avail_bf_3C48']:
                    mr.Markdown(r'- #####' + f)
    
                    
        
#(3) FILTERING
hidden = toggle_menu.value != '(3) Filter Weights'
#if not hidden:
#    pass
    
#(4) SCATTERING
#widgets for scattering dashboard
hidden = toggle_menu.value != '(4) Scattering Analysis'
#if not hidden:
#    pass
    
#(5) SCINTILLATION
hidden = toggle_menu.value != '(5) Scintillation Analysis'
#if not hidden:
#    pass

#(6) RM ANALYSIS

#widgets for filter weights dashboard
hidden = toggle_menu.value != '(6) RM Synthesis'
if not hidden:
    # display the output of the logfile
    mr.Markdown(" Log:")
    #if showlogcal.value:# or refreshlogbutton.clicked:
    flog = open(RMcal.logfile,"r")
    logtext = flog.read()
    flog.close()
    mr.Markdown(text=(logtext.replace('\n','\n\n')))
#    mr.Markdown("#### RM Budget")
#    parsec.RM_Budget_screen(trialz)
    
    
#(7) RM, DM, Bfield Budget

#widgets for filter weights dashboard
hidden = toggle_menu.value != '(7) RM, DM, Bfield Budget'
if not hidden:
    
    # display the output of the logfile
    mr.Markdown(" Log:")
    #if showlogcal.value:# or refreshlogbutton.clicked:
    flog = open(RMcal.logfile,"r")
    logtext = flog.read()
    flog.close()
    mr.Markdown(text=(logtext.replace('\n','\n\n')))
    
    
#(8) POLARIZATION ANALYSIS
hidden = toggle_menu.value != '(8) Polarization Analysis'
#if not hidden:
#    pass
    
#(9) ARCHIVE
#widgets for pol analysis dashboard
hidden = toggle_menu.value != '(9) Archive Data'
#if not hidden:
#    pass
    
nbox

# %%
nbox = None
#(0) LOAD DATA
hidden = toggle_menu.value != '(0) Load Data'
#if not hidden:
#    pass
    
#(1) DEDISPERSION

hidden=toggle_menu.value != '(1) Dedispersion Tuning'
#if not hidden:
#    pass

    
#(2) CALIBRATION



hidden = ('Calibration' not in toggle_menu.value ) or (not ADMINMODE)
if not hidden:
    
    mr.Markdown(" Selected 3C286 Pol Cal Files:")
    #display voltages and beamformer weight files for current selection
    if polcaldate_bf_menu.value != "":
        #display filterbank files if they exist
        if 'polcal_avail_3C286' in parsec.polcal_dict.keys():
            if len(parsec.polcal_dict['polcal_avail_3C286']) == 0:
                mr.Markdown(text=r'###### **3C286 Voltages:** None Found')
            else:
                mr.Markdown(text=r'###### **3C286 Voltages:** ')
                for f in parsec.polcal_dict['polcal_avail_3C286']:
                    mr.Markdown(r'- ######' + f)
        if 'polcal_avail_bf_3C286' in parsec.polcal_dict.keys():
            if len(parsec.polcal_dict['polcal_avail_bf_3C286']) == 0:
                mr.Markdown(text=r'##### **3C286 Beamformer Weights:** None Found')
            else:
                mr.Markdown(text=r'##### **3C286 Beamformer Weights:** ')
                for f in parsec.polcal_dict['polcal_avail_bf_3C286']:
                    mr.Markdown(r'- #####' + f)
    
    
#(3) FILTERING
hidden = toggle_menu.value != '(3) Filter Weights'
#if not hidden:
#    pass
    
#(4) SCATTERING
#widgets for scattering dashboard
hidden = toggle_menu.value != '(4) Scattering Analysis'
#if not hidden:
#    pass
    
#(5) SCINTILLATION
hidden = toggle_menu.value != '(5) Scintillation Analysis'
#if not hidden:
#    pass

#(6) RM ANALYSIS

#widgets for filter weights dashboard
hidden = toggle_menu.value != '(6) RM Synthesis'
#if not hidden:
#    mr.Markdown("#### Host B Field Estimate")
#    parsec.Bfield_Budget_screen()
    
#(7) RM, DM, Bfield Budget

#widgets for filter weights dashboard
hidden = toggle_menu.value != '(7) RM, DM, Bfield Budget'

#(8) POLARIZATION ANALYSIS
hidden = toggle_menu.value != '(8) Polarization Analysis'
#if not hidden:
#    pass
    
#(9) ARCHIVE
#widgets for pol analysis dashboard
hidden = toggle_menu.value != '(9) Archive Data'
#if not hidden:
#    pass
    
nbox

# %%
nbox = None
#(0) LOAD DATA
hidden = toggle_menu.value != '(0) Load Data'
#if not hidden:
#    pass
    
#(1) DEDISPERSION

hidden=toggle_menu.value != '(1) Dedispersion Tuning'
#if not hidden:
#    pass

    
#(2) CALIBRATION



hidden = ('Calibration' not in toggle_menu.value ) or (not ADMINMODE)
if not hidden:
    #display beam numbers for each cal pass
    mr.Markdown(" Table of Local Pol Cal Filterbanks:")
    nbox = mr.Table(data=parsec.df_beams,width="200px") 
    

#(3) FILTERING
hidden = toggle_menu.value != '(3) Filter Weights'
#if not hidden:
#    pass
    
#(4) SCATTERING
#widgets for scattering dashboard
hidden = toggle_menu.value != '(4) Scattering Analysis'
#if not hidden:
#    pass
    
#(5) SCINTILLATION
hidden = toggle_menu.value != '(5) Scintillation Analysis'
#if not hidden:
#    pass

#(6) RM ANALYSIS

#widgets for filter weights dashboard
hidden = toggle_menu.value != '(6) RM Synthesis'
#if not hidden:
#    # display the output of the logfile
#    mr.Markdown(" Log:")
    #if showlogcal.value:# or refreshlogbutton.clicked:
#    flog = open(RMcal.logfile,"r")
#    logtext = flog.read()
#    flog.close()
#    mr.Markdown(text=(logtext.replace('\n','\n\n')))
    
#(7) RM, DM, Bfield Budget

#widgets for filter weights dashboard
hidden = toggle_menu.value != '(7) RM, DM, Bfield Budget'
    
#(8) POLARIZATION ANALYSIS
hidden = toggle_menu.value != '(8) Polarization Analysis'
#if not hidden:
#    pass
    
#(9) ARCHIVE
#widgets for pol analysis dashboard
hidden = toggle_menu.value != '(9) Archive Data'
#if not hidden:
#    pass
    
nbox

# %%
nbox = None
#(0) LOAD DATA
hidden = toggle_menu.value != '(0) Load Data'
#if not hidden:
#    pass
    
#(1) DEDISPERSION

hidden=toggle_menu.value != '(1) Dedispersion Tuning'
#if not hidden:
#    pass

    
#(2) CALIBRATION



hidden = ('Calibration' not in toggle_menu.value ) or (not ADMINMODE)
if not hidden:
    #3C48 
    mr.Markdown(" Selected 3C48 Filterbanks and Weights:")
    if obsid3C48_menu.value != '':
        obs_files,obs_ids = polcal.get_calfil_files('3C48',polcaldate_findbeams_menu.value,obsid3C48_menu.value)
        if len(obs_files) == 0: mr.Markdown(text = r'##### **' + obsid3C48_menu.value + ' Filterbanks:** None Found')
        else:
            mr.Markdown(text=r'##### **' + obsid3C48_menu.value + ' Filterbanks:**')
            for f in obs_files:
                mr.Markdown(r'- #####' + f)

        if obsid3C48_menu.value in parsec.df_beams.index.tolist():#beam_dict_3C48.keys():
            #print(beam_dict_3C48.keys())
            mr.Markdown(text=r'##### **' + obsid3C48_menu.value + ' Beamformer Weights:**')
            #print(polcal.bfweights_output_path + "*" + polcal.VLANAME_DICT['3C48'] + "*" + parsec.df_beams['beamformer weights'].loc[obsid3C48_menu.value][:19] + "*")
            bf_files = glob.glob(polcal.bfweights_output_path + "*" + polcal.VLANAME_DICT['3C48'] + "*" + parsec.df_beams['beamformer weights'].loc[obsid3C48_menu.value][:19] + "*")
            for f in bf_files:
                mr.Markdown(text = r'- #####' + f)
        else:
            mr.Markdown(text = r'##### **' + obsid3C48_menu.value + ' Beamformer Weights:** None Found')

    
    
#(3) FILTERING
hidden = toggle_menu.value != '(3) Filter Weights'
#if not hidden:
#    pass
    
#(4) SCATTERING
#widgets for scattering dashboard
hidden = toggle_menu.value != '(4) Scattering Analysis'
#if not hidden:
#    pass
    
#(5) SCINTILLATION
hidden = toggle_menu.value != '(5) Scintillation Analysis'
#if not hidden:
#    pass

#(6) RM ANALYSIS

#widgets for filter weights dashboard
hidden = toggle_menu.value != '(6) RM Synthesis'
#if not hidden:
#    pass

#(7) RM, DM, Bfield Budget

#widgets for filter weights dashboard
hidden = toggle_menu.value != '(7) RM, DM, Bfield Budget'


#(8) POLARIZATION ANALYSIS
hidden = toggle_menu.value != '(8) Polarization Analysis'
#if not hidden:
#    pass
    
#(9) ARCHIVE
#widgets for pol analysis dashboard
hidden = toggle_menu.value != '(9) Archive Data'
#if not hidden:
#    pass
    
nbox

# %%
nbox = None
#(0) LOAD DATA
hidden = toggle_menu.value != '(0) Load Data'
#if not hidden:
#    pass
    
#(1) DEDISPERSION

hidden=toggle_menu.value != '(1) Dedispersion Tuning'
#if not hidden:
#    pass

    
#(2) CALIBRATION



hidden = ('Calibration' not in toggle_menu.value ) or (not ADMINMODE)
if not hidden:
    
    #3C286
    mr.Markdown(" Selected 3C286 Filterbanks and Weights:")
    if obsid3C286_menu.value != '':
        obs_files,obs_ids = polcal.get_calfil_files('3C286',polcaldate_findbeams_menu.value,obsid3C286_menu.value)
        if len(obs_files) == 0: mr.Markdown(text = r'##### **' + obsid3C286_menu.value + ' Filterbanks:** None Found')
        else:
            mr.Markdown(text=r'##### **' + obsid3C286_menu.value + ' Filterbanks:**')
            for f in obs_files:
                mr.Markdown(text = r'- #####' + f)

        if obsid3C286_menu.value in parsec.df_beams.index.tolist():
            mr.Markdown(text=r'##### **' + obsid3C286_menu.value + ' Beamformer Weights:**')
            bf_files = glob.glob(polcal.bfweights_output_path + "*" + polcal.VLANAME_DICT['3C286'] + "*" + parsec.df_beams['beamformer weights'].loc[obsid3C286_menu.value][:19] + "*")
            #print(polcal.bfweights_output_path + "*" + polcal.VLANAME_DICT['3C286'] + "*" + parsec.df_beams['beamformer weights'].loc[obsid3C286_menu.value][:19] +  "*")
            for f in bf_files:
                mr.Markdown(text = r'- #####' + f)
        else:
            mr.Markdown(text=r'##### **' + obsid3C286_menu.value + ' Beamformer Weights:** None Found')

#(3) FILTERING
hidden = toggle_menu.value != '(3) Filter Weights'
#if not hidden:
#    pass
    
#(4) SCATTERING
#widgets for scattering dashboard
hidden = toggle_menu.value != '(4) Scattering Analysis'
#if not hidden:
#    pass
    
#(5) SCINTILLATION
hidden = toggle_menu.value != '(5) Scintillation Analysis'
#if not hidden:
#    pass

#(6) RM ANALYSIS

#widgets for filter weights dashboard
hidden = toggle_menu.value != '(6) RM Synthesis'
#if not hidden:
#    pass


#(7) RM, DM, Bfield Budget

#widgets for filter weights dashboard
hidden = toggle_menu.value != '(7) RM, DM, Bfield Budget'


#(8) POLARIZATION ANALYSIS
hidden = toggle_menu.value != '(8) Polarization Analysis'
#if not hidden:
#    pass
    
#(9) ARCHIVE
#widgets for pol analysis dashboard
hidden = toggle_menu.value != '(9) Archive Data'
#if not hidden:
#    pass
    
nbox

# %%
nbox = None
#(0) LOAD DATA
hidden = toggle_menu.value != '(0) Load Data'
#if not hidden:
#    pass
    
#(1) DEDISPERSION

hidden=toggle_menu.value != '(1) Dedispersion Tuning'
#if not hidden:
#    pass

    
#(2) CALIBRATION



hidden = ('Calibration' not in toggle_menu.value ) or (not ADMINMODE)
if not hidden:
    
    
    # display the output of the logfile
    mr.Markdown(" Log:")
    #if showlogcal.value:# or refreshlogbutton.clicked:
    flog = open(polcal.logfile,"r")
    logtext = flog.read()
    flog.close()
    mr.Markdown(text=(logtext.replace('\n','\n\n')))
    
#(3) FILTERING
hidden = toggle_menu.value != '(3) Filter Weights'
#if not hidden:
#    pass
    
#(4) SCATTERING
#widgets for scattering dashboard
hidden = toggle_menu.value != '(4) Scattering Analysis'
#if not hidden:
#    pass
    
#(5) SCINTILLATION
hidden = toggle_menu.value != '(5) Scintillation Analysis'
#if not hidden:
#    pass

#(6) RM ANALYSIS

#widgets for filter weights dashboard
hidden = toggle_menu.value != '(6) RM Synthesis'
#if not hidden:
#    pass


#(7) RM, DM, Bfield Budget

#widgets for filter weights dashboard
hidden = toggle_menu.value != '(7) RM, DM, Bfield Budget'


#(8) POLARIZATION ANALYSIS
hidden = toggle_menu.value != '(8) Polarization Analysis'
#if not hidden:
#    pass
    
#(9) ARCHIVE
#widgets for pol analysis dashboard
hidden = toggle_menu.value != '(9) Archive Data'
#if not hidden:
#    pass
    
nbox
